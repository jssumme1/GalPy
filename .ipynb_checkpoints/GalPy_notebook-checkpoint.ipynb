# %%
import os
from glob import glob
from tqdm import tqdm
import importlib

import matplotlib
# %matplotlib inline

import Galfit
importlib.reload(Galfit)
# Out:
# <module 'Galfit' from '/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py'>

# %%
# PARAMETERS THAT CHANGE FOR DIFFERENT DATASETS AND OBJECTS *******
field = 'clio'
date = '20230718'
img_size = 100 # (max = 333/2)
psf_size = 100 # usually 100 for both sizes
star = False

# %%
#directories
image_dir = f'/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/{field}/mosaics'
object_dir = f'/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/{field}/objects'
psf_dir =  f'/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/{field}/psfs'

# catalog
cat_dir = f'/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/{field}/cats'
master_cat = os.path.join(cat_dir, f'{field.upper()}_total_cat_extinction.txt')
cats = glob(os.path.join(cat_dir, f'{field.upper()}_F*_cat.txt'))
cats.sort()

# i2d images
images = glob(os.path.join(image_dir, f'mosaic_{field}_nircam_*_30mas_{date}_i2d.fits'))
images.sort()

# %%
# initialize galfit and create psf cutouts
gal = Galfit.Galfit(field, images, cats, master_cat, img_size=img_size, psf_size=psf_size, star=star,
             image_dir=image_dir, object_dir=object_dir, psf_dir=psf_dir, cat_dir=cat_dir)
# Out:
# Creating PSF cutouts...: 100%|████████████████████| 6/6 [00:00<00:00, 53.42it/s]

# %%
clio_cool_objects = [3061, 4143, 417, 64, 19, 7, 1645, 1543, 4858, 4763, 4385, 1062, 988, 530, 767, 739, 629, 433, 475, 3906, 1620, 4717, 4741, 4764, 4509, 1315, 1591, 627, 1179, 383]
g191_cool_objects = [5263, 2635, 1949, 1503, 677, 874, 1509, 422, 2013, 1780, 1763, 2004, 2764, 3003, 4560, 5033, 4962, 4795, 5300, 4840, 4827, 4763, 5359, 6175, 8994, 8637]

# %%
obj_id = 383 

gal.make_object(obj_id, overwrite=True)
# Out:
# Creating object cutouts...: 100%|█████████████████| 6/6 [00:00<00:00, 14.04it/s]

# %%
# run
for im in tqdm(images, desc='Running GALFIT...'):
    filt = im.split('_')[-4]
    gal.add_component(obj_id, filt, 'sersic', bulge=True)
    gal.add_component(obj_id, filt, 'sersic', bulge=False)
    
    gal.add_constraints(obj_id, filt, '1-2  mag  -2 2') # constrain bulge and disk to be within a few magnitues
    gal.add_constraints(obj_id, filt, '1_2  x    ratio') # keeps x position fixed between components
    gal.add_constraints(obj_id, filt, '1_2  y    ratio') # keeps y position fixed between components
    gal.add_constraints(obj_id, filt, '1    n    2 to 10') # fix bulge sersic index between 2 and 10
    gal.add_constraints(obj_id, filt, '2    n    0.4 to 3') # fix disk sersic index between 0.4 to 5
    gal.add_constraints(obj_id, filt, '1-2  n    0.1 10') # force bulge sersic > disk sersic
    gal.add_constraints(obj_id, filt, '1_2  pa   ratio') # keeps position angle fixed between components
    gal.add_constraints(obj_id, filt, '1/2  9    0.7 1.3') # keeps axis ratio similar between components
    gal.add_constraints(obj_id, filt, '2/1  re   0.2 5') # fix disk/bulge half light radius to be ratio 1 to 8
    
    gal.run(obj_id, filt, num='01', overwrite=True)
# Out:
# Running GALFIT...:   0%|                                  | 0/6 [00:00<?, ?it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_383_f090w_sci.fits      # Input data image (FITS file)
# B) obj_383_f090w_imgblock01.fits      # Output data image block
# C) obj_383_f090w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f090w_webbpsf_cutout.fits          # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_383_f090w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.030  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 0                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.0000 100.0000 1 1  #  Position x, y
#  3) 20.9675     1          #  Integrated magnitude
#  4) 2.0483      1          #  R_e (effective radius)   [pix]
#  5) 5.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.4661      1          #  Axis ratio (b/a)
# 10) 202.9900    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.0000 100.0000 1 1  #  Position x, y
#  3) 20.9675     1          #  Integrated magnitude
#  4) 4.0967      1          #  R_e (effective radius)   [pix]
#  5) 1.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.4661      1          #  Axis ratio (b/a)
# 10) 202.9900    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
# ================================================================================
# Initial parameters:
#  sersic    : (  100.00,   100.00)   20.97      2.05    5.00    0.47    22.99
#  sersic    : ( {100.00}, {100.00})  20.97      4.10    1.00    0.47   {22.99}
# ================================================================================
#
# Iteration : 1     Chi2nu: 8.381e+01     dChi2/Chi2: -3.01e+20   alamda: 1e-03
#  sersic    : (   99.98,   100.10)   21.51      4.30    9.42    0.51    21.45
#  sersic    : (  {99.98}, {100.10})  21.89      4.04    1.25    0.47   {21.45}
# COUNTDOWN = 99
#
# Iteration : 2     Chi2nu: 2.687e+01     dChi2/Chi2: -2.12e+00   alamda: 1e-04
#  sersic    : (   99.93,   100.35)   20.91     18.56  *10.00*   0.84    17.43
#  sersic    : (  {99.93}, {100.35})  22.76      5.28    1.76    0.64   {17.43}
# COUNTDOWN = 98
#
# Iteration : 3     Chi2nu: 7.829e+00     dChi2/Chi2: -2.43e+00   alamda: 1e-05
#  sersic    : (   99.91,   100.80)   21.07     39.06    8.60    0.70    -2.17
#  sersic    : (  {99.91}, {100.80})  22.15     11.31    2.81    1.00   {-2.17}
# COUNTDOWN = 97
#
# Iteration : 4     Chi2nu: 7.829e+00     dChi2/Chi2: 2.36e-08    alamda: 1e-04
#  sersic    : (   99.91,   100.80)   21.07     39.06    8.60    0.70    -2.17
#  sersic    : (  {99.91}, {100.80})  22.15     11.31    2.81    1.00   {-2.17}
# COUNTDOWN = 10
#
# Iteration : 5     Chi2nu: 7.829e+00     dChi2/Chi2: 2.36e-08    alamda: 1e-03
#  sersic    : (   99.91,   100.80)   21.07     39.06    8.60    0.70    -2.17
#  sersic    : (  {99.91}, {100.80})  22.15     11.31    2.81    1.00   {-2.17}
# COUNTDOWN = 9
#
# Iteration : 6     Chi2nu: 4.502e+00     dChi2/Chi2: -7.39e-01   alamda: 1e-04
#  sersic    : (   99.88,   101.93)   20.97     55.77    5.78    0.37    -7.96
#  sersic    : (  {99.88}, {101.93})  22.91     11.15    3.00    0.53   {-7.96}
# COUNTDOWN = 94
#
# Iteration : 7     Chi2nu: 2.312e+00     dChi2/Chi2: -9.47e-01   alamda: 1e-05
#  sersic    : (  100.05,   104.42)   20.65    115.04  *10.00*   0.55    -8.47
#  sersic    : ( {100.05}, {104.42})  21.88     23.01    3.00    0.79   {-8.47}
# COUNTDOWN = 93
#
# Iteration : 8     Chi2nu: 2.312e+00     dChi2/Chi2: -3.82e-10   alamda: 1e-04
#  sersic    : (  100.05,   104.42)   20.65    115.04  *10.00*   0.55    -8.47
#  sersic    : ( {100.05}, {104.42})  21.88     23.01    3.00    0.79   {-8.47}
# COUNTDOWN = 10
#
# Iteration : 9     Chi2nu: 2.312e+00     dChi2/Chi2: -3.82e-10   alamda: 1e-03
#  sersic    : (  100.05,   104.42)   20.65    115.04  *10.00*   0.55    -8.47
#  sersic    : ( {100.05}, {104.42})  21.88     23.01    3.00    0.79   {-8.47}
# COUNTDOWN = 9
#
# Iteration : 10    Chi2nu: 2.312e+00     dChi2/Chi2: -3.82e-10   alamda: 1e-02
#  sersic    : (  100.05,   104.42)   20.65    115.04  *10.00*   0.55    -8.47
#  sersic    : ( {100.05}, {104.42})  21.88     23.01    3.00    0.79   {-8.47}
# COUNTDOWN = 8
#
# Iteration : 11    Chi2nu: 2.312e+00     dChi2/Chi2: -3.82e-10   alamda: 1e-01
#  sersic    : (  100.05,   104.42)   20.65    115.04  *10.00*   0.55    -8.47
#  sersic    : ( {100.05}, {104.42})  21.88     23.01    3.00    0.79   {-8.47}
# COUNTDOWN = 7
#
# Iteration : 12    Chi2nu: 2.312e+00     dChi2/Chi2: -3.82e-10   alamda: 1e+00
#  sersic    : (  100.05,   104.42)   20.65    115.04  *10.00*   0.55    -8.47
#  sersic    : ( {100.05}, {104.42})  21.88     23.01    3.00    0.79   {-8.47}
# COUNTDOWN = 6
#
# Iteration : 13    Chi2nu: 2.050e+00     dChi2/Chi2: -1.28e-01   alamda: 1e-01
#  sersic    : (  100.02,   104.29)   20.64    102.87  *10.00*   0.67   -11.33
#  sersic    : ( {100.02}, {104.29})  21.82     20.57    3.00    0.87  {-11.33}
# COUNTDOWN = 87
#
# Iteration : 14    Chi2nu: 2.050e+00     dChi2/Chi2: 2.21e-08    alamda: 1e+00
#  sersic    : (  100.02,   104.29)   20.64    102.87  *10.00*   0.67   -11.33
#  sersic    : ( {100.02}, {104.29})  21.82     20.57    3.00    0.87  {-11.33}
# COUNTDOWN = 10
#
# Iteration : 15    Chi2nu: 1.896e+00     dChi2/Chi2: -8.13e-02   alamda: 1e-01
#  sersic    : (  100.00,   104.28)   20.65     93.84  *10.00*   0.76   -16.12
#  sersic    : ( {100.00}, {104.28})  21.81     18.77    3.00    0.87  {-16.12}
# COUNTDOWN = 85
#
# Iteration : 16    Chi2nu: 1.896e+00     dChi2/Chi2: 3.89e-08    alamda: 1e+00
#  sersic    : (  100.00,   104.28)   20.65     93.84  *10.00*   0.76   -16.12
#  sersic    : ( {100.00}, {104.28})  21.81     18.77    3.00    0.87  {-16.12}
# COUNTDOWN = 10
#
# Iteration : 17    Chi2nu: 1.790e+00     dChi2/Chi2: -5.93e-02   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.66     87.14  *10.00*   0.83   -22.12
#  sersic    : (  {99.99}, {104.27})  21.82     17.43    3.00    0.83  {-22.12}
# COUNTDOWN = 83
#
# Iteration : 18    Chi2nu: 1.790e+00     dChi2/Chi2: 1.17e-09    alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.66     87.14  *10.00*   0.83   -22.12
#  sersic    : (  {99.99}, {104.27})  21.82     17.43    3.00    0.83  {-22.12}
# COUNTDOWN = 10
#
# Iteration : 19    Chi2nu: 1.711e+00     dChi2/Chi2: -4.62e-02   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.68     81.94  *10.00*   0.88   -27.72
#  sersic    : (  {99.99}, {104.27})  21.83     16.39    3.00    0.79  {-27.72}
# COUNTDOWN = 81
#
# Iteration : 20    Chi2nu: 1.711e+00     dChi2/Chi2: 4.14e-08    alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.68     81.94  *10.00*   0.88   -27.72
#  sersic    : (  {99.99}, {104.27})  21.83     16.39    3.00    0.79  {-27.72}
# COUNTDOWN = 10
#
# Iteration : 21    Chi2nu: 1.649e+00     dChi2/Chi2: -3.70e-02   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.70     77.68  *10.00*   0.92   -32.01
#  sersic    : (  {99.99}, {104.27})  21.84     15.54    3.00    0.75  {-32.01}
# COUNTDOWN = 79
#
# Iteration : 22    Chi2nu: 1.649e+00     dChi2/Chi2: 1.11e-08    alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.70     77.68  *10.00*   0.92   -32.01
#  sersic    : (  {99.99}, {104.27})  21.84     15.54    3.00    0.75  {-32.01}
# COUNTDOWN = 10
#
# Iteration : 23    Chi2nu: 1.607e+00     dChi2/Chi2: -2.65e-02   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.72     74.03  *10.00*   0.95   -35.13
#  sersic    : (  {99.99}, {104.27})  21.85     14.81    3.00    0.73  {-35.13}
# COUNTDOWN = 77
#
# Iteration : 24    Chi2nu: 1.607e+00     dChi2/Chi2: 1.27e-08    alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.72     74.03  *10.00*   0.95   -35.13
#  sersic    : (  {99.99}, {104.27})  21.85     14.81    3.00    0.73  {-35.13}
# COUNTDOWN = 10
#
# Iteration : 25    Chi2nu: 1.558e+00     dChi2/Chi2: -3.16e-02   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.74     70.84  *10.00*   0.91   -37.55
#  sersic    : (  {99.99}, {104.27})  21.86     14.17    3.00    0.70  {-37.55}
# COUNTDOWN = 75
#
# Iteration : 26    Chi2nu: 1.558e+00     dChi2/Chi2: -3.10e-08   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.74     70.84  *10.00*   0.91   -37.55
#  sersic    : (  {99.99}, {104.27})  21.86     14.17    3.00    0.70  {-37.55}
# COUNTDOWN = 10
#
# Iteration : 27    Chi2nu: 1.547e+00     dChi2/Chi2: -6.67e-03   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.77     68.23  *10.00*   0.96   -38.91
#  sersic    : (  {99.99}, {104.27})  21.87     13.65    3.00    0.74  {-38.91}
# COUNTDOWN = 73
#
# Iteration : 28    Chi2nu: 1.547e+00     dChi2/Chi2: 1.33e-10    alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.77     68.23  *10.00*   0.96   -38.91
#  sersic    : (  {99.99}, {104.27})  21.87     13.65    3.00    0.74  {-38.91}
# COUNTDOWN = 10
#
# Iteration : 29    Chi2nu: 1.508e+00     dChi2/Chi2: -2.59e-02   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.79     65.69  *10.00*   0.91   -40.13
#  sersic    : (  {99.99}, {104.27})  21.87     13.14    3.00    0.70  {-40.13}
# COUNTDOWN = 71
#
# Iteration : 30    Chi2nu: 1.508e+00     dChi2/Chi2: -2.04e-08   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.79     65.69  *10.00*   0.91   -40.13
#  sersic    : (  {99.99}, {104.27})  21.87     13.14    3.00    0.70  {-40.13}
# COUNTDOWN = 10
#
# Iteration : 31    Chi2nu: 1.502e+00     dChi2/Chi2: -4.02e-03   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.81     63.64  *10.00*   0.97   -40.91
#  sersic    : (  {99.99}, {104.27})  21.88     12.73    3.00    0.74  {-40.91}
# COUNTDOWN = 69
#
# Iteration : 32    Chi2nu: 1.502e+00     dChi2/Chi2: -2.58e-08   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.81     63.64  *10.00*   0.97   -40.91
#  sersic    : (  {99.99}, {104.27})  21.88     12.73    3.00    0.74  {-40.91}
# COUNTDOWN = 10
#
# Iteration : 33    Chi2nu: 1.473e+00     dChi2/Chi2: -2.00e-02   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.82     61.59  *10.00*   0.92   -41.58
#  sersic    : (  {99.99}, {104.27})  21.88     12.32    3.00    0.71  {-41.58}
# COUNTDOWN = 67
#
# Iteration : 34    Chi2nu: 1.473e+00     dChi2/Chi2: 2.99e-08    alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.82     61.59  *10.00*   0.92   -41.58
#  sersic    : (  {99.99}, {104.27})  21.88     12.32    3.00    0.71  {-41.58}
# COUNTDOWN = 10
#
# Iteration : 35    Chi2nu: 1.470e+00     dChi2/Chi2: -1.97e-03   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.84     59.95  *10.00*   0.97   -42.10
#  sersic    : (  {99.99}, {104.27})  21.88     11.99    2.97    0.75  {-42.10}
# COUNTDOWN = 65
#
# Iteration : 36    Chi2nu: 1.470e+00     dChi2/Chi2: 8.86e-09    alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.84     59.95  *10.00*   0.97   -42.10
#  sersic    : (  {99.99}, {104.27})  21.88     11.99    2.97    0.75  {-42.10}
# COUNTDOWN = 10
#
# Iteration : 37    Chi2nu: 1.448e+00     dChi2/Chi2: -1.50e-02   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.86     58.28  *10.00*   0.93   -42.50
#  sersic    : (  {99.99}, {104.27})  21.88     11.66    2.93    0.71  {-42.50}
# COUNTDOWN = 63
#
# Iteration : 38    Chi2nu: 1.448e+00     dChi2/Chi2: -2.05e-08   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.86     58.28  *10.00*   0.93   -42.50
#  sersic    : (  {99.99}, {104.27})  21.88     11.66    2.93    0.71  {-42.50}
# COUNTDOWN = 10
#
# Iteration : 39    Chi2nu: 1.447e+00     dChi2/Chi2: -5.63e-04   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.88     56.94  *10.00*   0.98   -42.86
#  sersic    : (  {99.99}, {104.27})  21.89     11.39    2.87    0.75  {-42.86}
# COUNTDOWN = 61
#
# Iteration : 40    Chi2nu: 1.447e+00     dChi2/Chi2: -3.54e-09   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.88     56.94  *10.00*   0.98   -42.86
#  sersic    : (  {99.99}, {104.27})  21.89     11.39    2.87    0.75  {-42.86}
# COUNTDOWN = 10
#
# Iteration : 41    Chi2nu: 1.431e+00     dChi2/Chi2: -1.18e-02   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.89     55.53  *10.00*   0.93   -43.07
#  sersic    : (  {99.99}, {104.27})  21.89     11.11    2.81    0.72  {-43.07}
# COUNTDOWN = 59
#
# Iteration : 42    Chi2nu: 1.431e+00     dChi2/Chi2: -5.43e-09   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.89     55.53  *10.00*   0.93   -43.07
#  sersic    : (  {99.99}, {104.27})  21.89     11.11    2.81    0.72  {-43.07}
# COUNTDOWN = 10
#
# Iteration : 43    Chi2nu: 1.430e+00     dChi2/Chi2: -8.75e-05   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.91     54.38  *10.00*   0.98   -43.32
#  sersic    : (  {99.99}, {104.27})  21.89     10.88    2.75    0.75  {-43.32}
# COUNTDOWN = 9
#
# Iteration : 44    Chi2nu: 1.430e+00     dChi2/Chi2: 1.50e-08    alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.91     54.38  *10.00*   0.98   -43.32
#  sersic    : (  {99.99}, {104.27})  21.89     10.88    2.75    0.75  {-43.32}
# COUNTDOWN = 8
#
# Iteration : 45    Chi2nu: 1.417e+00     dChi2/Chi2: -9.70e-03   alamda: 1e-01
#  sersic    : (   99.99,   104.27)   20.92     53.15  *10.00*   0.94   -43.43
#  sersic    : (  {99.99}, {104.27})  21.89     10.63    2.69    0.72  {-43.43}
# COUNTDOWN = 55
#
# Iteration : 46    Chi2nu: 1.417e+00     dChi2/Chi2: 2.68e-08    alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.92     53.15  *10.00*   0.94   -43.43
#  sersic    : (  {99.99}, {104.27})  21.89     10.63    2.69    0.72  {-43.43}
# COUNTDOWN = 10
#
# Iteration : 47    Chi2nu: 1.417e+00     dChi2/Chi2: 2.68e-08    alamda: 1e+01
#  sersic    : (   99.99,   104.27)   20.92     53.15  *10.00*   0.94   -43.43
#  sersic    : (  {99.99}, {104.27})  21.89     10.63    2.69    0.72  {-43.43}
# COUNTDOWN = 9
#
# Iteration : 48    Chi2nu: 1.414e+00     dChi2/Chi2: -1.68e-03   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.92     52.80  *10.00*   0.94   -43.44
#  sersic    : (  {99.99}, {104.27})  21.89     10.56    2.70    0.73  {-43.44}
# COUNTDOWN = 52
#
# Iteration : 49    Chi2nu: 1.414e+00     dChi2/Chi2: -1.22e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.27)   20.92     52.80  *10.00*   0.94   -43.44
#  sersic    : (  {99.99}, {104.27})  21.89     10.56    2.70    0.73  {-43.44}
# COUNTDOWN = 10
#
# Iteration : 50    Chi2nu: 1.412e+00     dChi2/Chi2: -1.37e-03   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.92     52.49  *10.00*   0.95   -43.46
#  sersic    : (  {99.99}, {104.27})  21.89     10.50    2.71    0.73  {-43.46}
# COUNTDOWN = 50
#
# Iteration : 51    Chi2nu: 1.412e+00     dChi2/Chi2: 3.39e-10    alamda: 1e+01
#  sersic    : (   99.99,   104.27)   20.92     52.49  *10.00*   0.95   -43.46
#  sersic    : (  {99.99}, {104.27})  21.89     10.50    2.71    0.73  {-43.46}
# COUNTDOWN = 10
#
# Iteration : 52    Chi2nu: 1.411e+00     dChi2/Chi2: -1.14e-03   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.92     52.21  *10.00*   0.95   -43.48
#  sersic    : (  {99.99}, {104.27})  21.89     10.44    2.72    0.73  {-43.48}
# COUNTDOWN = 48
#
# Iteration : 53    Chi2nu: 1.411e+00     dChi2/Chi2: -3.44e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.27)   20.92     52.21  *10.00*   0.95   -43.48
#  sersic    : (  {99.99}, {104.27})  21.89     10.44    2.72    0.73  {-43.48}
# COUNTDOWN = 10
#
# Iteration : 54    Chi2nu: 1.409e+00     dChi2/Chi2: -9.72e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.92     51.95  *10.00*   0.96   -43.51
#  sersic    : (  {99.99}, {104.27})  21.89     10.39    2.72    0.73  {-43.51}
# COUNTDOWN = 46
#
# Iteration : 55    Chi2nu: 1.409e+00     dChi2/Chi2: -2.75e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.27)   20.92     51.95  *10.00*   0.96   -43.51
#  sersic    : (  {99.99}, {104.27})  21.89     10.39    2.72    0.73  {-43.51}
# COUNTDOWN = 10
#
# Iteration : 56    Chi2nu: 1.408e+00     dChi2/Chi2: -8.42e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.93     51.72  *10.00*   0.96   -43.55
#  sersic    : (  {99.99}, {104.27})  21.89     10.34    2.73    0.74  {-43.55}
# COUNTDOWN = 44
#
# Iteration : 57    Chi2nu: 1.408e+00     dChi2/Chi2: -2.54e-09   alamda: 1e+01
#  sersic    : (   99.99,   104.27)   20.93     51.72  *10.00*   0.96   -43.55
#  sersic    : (  {99.99}, {104.27})  21.89     10.34    2.73    0.74  {-43.55}
# COUNTDOWN = 10
#
# Iteration : 58    Chi2nu: 1.407e+00     dChi2/Chi2: -9.18e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.93     51.50  *10.00*   0.95   -43.58
#  sersic    : (  {99.99}, {104.27})  21.89     10.30    2.74    0.73  {-43.58}
# COUNTDOWN = 42
#
# Iteration : 59    Chi2nu: 1.407e+00     dChi2/Chi2: -1.22e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.27)   20.93     51.50  *10.00*   0.95   -43.58
#  sersic    : (  {99.99}, {104.27})  21.89     10.30    2.74    0.73  {-43.58}
# COUNTDOWN = 10
#
# Iteration : 60    Chi2nu: 1.406e+00     dChi2/Chi2: -6.15e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.93     51.32  *10.00*   0.96   -43.63
#  sersic    : (  {99.99}, {104.27})  21.89     10.26    2.74    0.74  {-43.63}
# COUNTDOWN = 40
#
# Iteration : 61    Chi2nu: 1.406e+00     dChi2/Chi2: -2.74e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.27)   20.93     51.32  *10.00*   0.96   -43.63
#  sersic    : (  {99.99}, {104.27})  21.89     10.26    2.74    0.74  {-43.63}
# COUNTDOWN = 10
#
# Iteration : 62    Chi2nu: 1.405e+00     dChi2/Chi2: -5.66e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.27)   20.93     51.13  *10.00*   0.96   -43.67
#  sersic    : (  {99.99}, {104.27})  21.89     10.23    2.74    0.74  {-43.67}
# COUNTDOWN = 38
#
# Iteration : 63    Chi2nu: 1.399e+00     dChi2/Chi2: -4.74e-03   alamda: 1e-01
#  sersic    : (   99.99,   104.28)   20.95     48.87  *10.00*   0.99   -44.03
#  sersic    : (  {99.99}, {104.28})  21.90      9.77    2.66    0.76  {-44.03}
# COUNTDOWN = 37
#
# Iteration : 64    Chi2nu: 1.399e+00     dChi2/Chi2: -1.20e-08   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   20.95     48.87  *10.00*   0.99   -44.03
#  sersic    : (  {99.99}, {104.28})  21.90      9.77    2.66    0.76  {-44.03}
# COUNTDOWN = 10
#
# Iteration : 65    Chi2nu: 1.392e+00     dChi2/Chi2: -4.51e-03   alamda: 1e-01
#  sersic    : (   99.99,   104.28)   20.96     47.42  *10.00*   0.96   -44.43
#  sersic    : (  {99.99}, {104.28})  21.90      9.48    2.59    0.74  {-44.43}
# COUNTDOWN = 35
#
# Iteration : 66    Chi2nu: 1.392e+00     dChi2/Chi2: 2.19e-08    alamda: 1e+00
#  sersic    : (   99.99,   104.28)   20.96     47.42  *10.00*   0.96   -44.43
#  sersic    : (  {99.99}, {104.28})  21.90      9.48    2.59    0.74  {-44.43}
# COUNTDOWN = 10
#
# Iteration : 67    Chi2nu: 1.390e+00     dChi2/Chi2: -1.70e-03   alamda: 1e-01
#  sersic    : (   99.99,   104.28)   20.98     46.71  *10.00*   0.99   -44.72
#  sersic    : (  {99.99}, {104.28})  21.91      9.34    2.52    0.76  {-44.72}
# COUNTDOWN = 33
#
# Iteration : 68    Chi2nu: 1.390e+00     dChi2/Chi2: -3.48e-08   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   20.98     46.71  *10.00*   0.99   -44.72
#  sersic    : (  {99.99}, {104.28})  21.91      9.34    2.52    0.76  {-44.72}
# COUNTDOWN = 10
#
# Iteration : 69    Chi2nu: 1.388e+00     dChi2/Chi2: -1.76e-03   alamda: 1e-01
#  sersic    : (   99.99,   104.28)   20.99     46.48  *10.00*   0.96   -44.87
#  sersic    : (  {99.99}, {104.28})  21.92      9.30    2.47    0.74  {-44.87}
# COUNTDOWN = 31
#
# Iteration : 70    Chi2nu: 1.388e+00     dChi2/Chi2: -1.09e-08   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   20.99     46.48  *10.00*   0.96   -44.87
#  sersic    : (  {99.99}, {104.28})  21.92      9.30    2.47    0.74  {-44.87}
# COUNTDOWN = 10
#
# Iteration : 71    Chi2nu: 1.388e+00     dChi2/Chi2: -1.09e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.28)   20.99     46.48  *10.00*   0.96   -44.87
#  sersic    : (  {99.99}, {104.28})  21.92      9.30    2.47    0.74  {-44.87}
# COUNTDOWN = 9
#
# Iteration : 72    Chi2nu: 1.387e+00     dChi2/Chi2: -2.12e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   20.99     46.39  *10.00*   0.97   -44.88
#  sersic    : (  {99.99}, {104.28})  21.92      9.28    2.47    0.74  {-44.88}
# COUNTDOWN = 28
#
# Iteration : 73    Chi2nu: 1.387e+00     dChi2/Chi2: 1.07e-08    alamda: 1e+01
#  sersic    : (   99.99,   104.28)   20.99     46.39  *10.00*   0.97   -44.88
#  sersic    : (  {99.99}, {104.28})  21.92      9.28    2.47    0.74  {-44.88}
# COUNTDOWN = 10
#
# Iteration : 74    Chi2nu: 1.387e+00     dChi2/Chi2: -1.76e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.00     46.30  *10.00*   0.97   -44.88
#  sersic    : (  {99.99}, {104.28})  21.92      9.26    2.47    0.75  {-44.88}
# COUNTDOWN = 26
#
# Iteration : 75    Chi2nu: 1.387e+00     dChi2/Chi2: -1.10e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.00     46.30  *10.00*   0.97   -44.88
#  sersic    : (  {99.99}, {104.28})  21.92      9.26    2.47    0.75  {-44.88}
# COUNTDOWN = 10
#
# Iteration : 76    Chi2nu: 1.387e+00     dChi2/Chi2: -1.53e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.00     46.20  *10.00*   0.97   -44.88
#  sersic    : (  {99.99}, {104.28})  21.92      9.24    2.47    0.75  {-44.88}
# COUNTDOWN = 24
#
# Iteration : 77    Chi2nu: 1.387e+00     dChi2/Chi2: -1.65e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.00     46.20  *10.00*   0.97   -44.88
#  sersic    : (  {99.99}, {104.28})  21.92      9.24    2.47    0.75  {-44.88}
# COUNTDOWN = 10
#
# Iteration : 78    Chi2nu: 1.387e+00     dChi2/Chi2: -1.37e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.00     46.11  *10.00*   0.97   -44.89
#  sersic    : (  {99.99}, {104.28})  21.92      9.22    2.47    0.75  {-44.89}
# COUNTDOWN = 22
#
# Iteration : 79    Chi2nu: 1.387e+00     dChi2/Chi2: 2.27e-08    alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.00     46.11  *10.00*   0.97   -44.89
#  sersic    : (  {99.99}, {104.28})  21.92      9.22    2.47    0.75  {-44.89}
# COUNTDOWN = 10
#
# Iteration : 80    Chi2nu: 1.386e+00     dChi2/Chi2: -2.09e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.00     46.01  *10.00*   0.97   -44.90
#  sersic    : (  {99.99}, {104.28})  21.92      9.20    2.48    0.75  {-44.90}
# COUNTDOWN = 20
#
# Iteration : 81    Chi2nu: 1.386e+00     dChi2/Chi2: -1.51e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.00     46.01  *10.00*   0.97   -44.90
#  sersic    : (  {99.99}, {104.28})  21.92      9.20    2.48    0.75  {-44.90}
# COUNTDOWN = 10
#
# Iteration : 82    Chi2nu: 1.386e+00     dChi2/Chi2: -1.14e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.00     45.93  *10.00*   0.97   -44.91
#  sersic    : (  {99.99}, {104.28})  21.92      9.19    2.48    0.75  {-44.91}
# COUNTDOWN = 18
#
# Iteration : 83    Chi2nu: 1.386e+00     dChi2/Chi2: 2.89e-08    alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.00     45.93  *10.00*   0.97   -44.91
#  sersic    : (  {99.99}, {104.28})  21.92      9.19    2.48    0.75  {-44.91}
# COUNTDOWN = 10
#
# Iteration : 84    Chi2nu: 1.386e+00     dChi2/Chi2: -1.04e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.00     45.84  *10.00*   0.98   -44.92
#  sersic    : (  {99.99}, {104.28})  21.92      9.17    2.48    0.75  {-44.92}
# COUNTDOWN = 16
#
# Iteration : 85    Chi2nu: 1.386e+00     dChi2/Chi2: 1.31e-09    alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.00     45.84  *10.00*   0.98   -44.92
#  sersic    : (  {99.99}, {104.28})  21.92      9.17    2.48    0.75  {-44.92}
# COUNTDOWN = 10
#
# Iteration : 86    Chi2nu: 1.386e+00     dChi2/Chi2: -1.85e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.00     45.76  *10.00*   0.97   -44.94
#  sersic    : (  {99.99}, {104.28})  21.92      9.15    2.48    0.75  {-44.94}
# COUNTDOWN = 14
#
# Iteration : 87    Chi2nu: 1.386e+00     dChi2/Chi2: 1.01e-08    alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.00     45.76  *10.00*   0.97   -44.94
#  sersic    : (  {99.99}, {104.28})  21.92      9.15    2.48    0.75  {-44.94}
# COUNTDOWN = 10
#
# Iteration : 88    Chi2nu: 1.386e+00     dChi2/Chi2: -8.86e-05   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.00     45.68  *10.00*   0.98   -44.95
#  sersic    : (  {99.99}, {104.28})  21.92      9.14    2.48    0.75  {-44.95}
# COUNTDOWN = 9
#
# Iteration : 89    Chi2nu: 1.386e+00     dChi2/Chi2: 2.01e-08    alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.00     45.68  *10.00*   0.98   -44.95
#  sersic    : (  {99.99}, {104.28})  21.92      9.14    2.48    0.75  {-44.95}
# COUNTDOWN = 8
#
# Iteration : 90    Chi2nu: 1.385e+00     dChi2/Chi2: -8.27e-05   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.00     45.60  *10.00*   0.98   -44.97
#  sersic    : (  {99.99}, {104.28})  21.92      9.12    2.48    0.75  {-44.97}
# COUNTDOWN = 7
#
# Iteration : 91    Chi2nu: 1.385e+00     dChi2/Chi2: 1.21e-08    alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.00     45.60  *10.00*   0.98   -44.97
#  sersic    : (  {99.99}, {104.28})  21.92      9.12    2.48    0.75  {-44.97}
# COUNTDOWN = 6
#
# Iteration : 92    Chi2nu: 1.385e+00     dChi2/Chi2: -1.68e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.00     45.53  *10.00*   0.98   -44.99
#  sersic    : (  {99.99}, {104.28})  21.92      9.11    2.47    0.75  {-44.99}
# COUNTDOWN = 8
#
# Iteration : 93    Chi2nu: 1.385e+00     dChi2/Chi2: -1.45e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.00     45.53  *10.00*   0.98   -44.99
#  sersic    : (  {99.99}, {104.28})  21.92      9.11    2.47    0.75  {-44.99}
# COUNTDOWN = 10
#
# Iteration : 94    Chi2nu: 1.385e+00     dChi2/Chi2: -7.23e-05   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.01     45.46  *10.00*   0.98   -45.00
#  sersic    : (  {99.99}, {104.28})  21.92      9.09    2.47    0.75  {-45.00}
# COUNTDOWN = 9
#
# Iteration : 95    Chi2nu: 1.385e+00     dChi2/Chi2: -1.10e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.01     45.46  *10.00*   0.98   -45.00
#  sersic    : (  {99.99}, {104.28})  21.92      9.09    2.47    0.75  {-45.00}
# COUNTDOWN = 8
#
# Iteration : 96    Chi2nu: 1.385e+00     dChi2/Chi2: -1.39e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.01     45.39  *10.00*   0.97   -45.02
#  sersic    : (  {99.99}, {104.28})  21.92      9.08    2.47    0.75  {-45.02}
# COUNTDOWN = 4
#
# Iteration : 97    Chi2nu: 1.385e+00     dChi2/Chi2: -2.03e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.01     45.39  *10.00*   0.97   -45.02
#  sersic    : (  {99.99}, {104.28})  21.92      9.08    2.47    0.75  {-45.02}
# COUNTDOWN = 10
#
# Iteration : 98    Chi2nu: 1.385e+00     dChi2/Chi2: -6.60e-05   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.01     45.32  *10.00*   0.98   -45.04
#  sersic    : (  {99.99}, {104.28})  21.92      9.06    2.47    0.75  {-45.04}
# COUNTDOWN = 9
#
# Iteration : 99    Chi2nu: 1.385e+00     dChi2/Chi2: -2.65e-08   alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.01     45.32  *10.00*   0.98   -45.04
#  sersic    : (  {99.99}, {104.28})  21.92      9.06    2.47    0.75  {-45.04}
# COUNTDOWN = 8
#
# Iteration : 100    Chi2nu: 1.385e+00     dChi2/Chi2: -5.91e-05   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.01     45.26  *10.00*   0.98   -45.06
#  sersic    : (  {99.99}, {104.28})  21.92      9.05    2.47    0.75  {-45.06}
# COUNTDOWN = 7
#
# Iteration : 101    Chi2nu: 1.385e+00     dChi2/Chi2: 2.48e-08    alamda: 1e+01
#  sersic    : (   99.99,   104.28)   21.01     45.26  *10.00*   0.98   -45.06
#  sersic    : (  {99.99}, {104.28})  21.92      9.05    2.47    0.75  {-45.06}
# COUNTDOWN = 6
#
# Iteration : 102    Chi2nu: 1.385e+00     dChi2/Chi2: -1.36e-04   alamda: 1e+00
#  sersic    : (   99.99,   104.28)   21.01     45.19  *10.00*   0.98   -45.08
#  sersic    : (  {99.99}, {104.28})  21.92      9.04    2.47    0.75  {-45.08}
# COUNTDOWN = -2
# Running GALFIT...:  17%|████▎                     | 1/6 [00:50<04:14, 50.96s/it]
#  The fitting ended because the maximum number of iterations
#  has been reached, not necessarily because of convergence!
#
#
#
# Fit summary is now being saved into `fit.log'.
#
# ================================================================================
# WARNING: Possible numerical problem detected with one or more output
#          parameters enclosed in *...*.  The solution is likely to be not
#          reliable.  Rerun fit by holding problematic parameters fixed
#          temporarily or setting them to other initial values.
# ================================================================================
#
#
#
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_383_f150w_sci.fits      # Input data image (FITS file)
# B) obj_383_f150w_imgblock01.fits      # Output data image block
# C) obj_383_f150w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f150w_webbpsf_cutout.fits          # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_383_f150w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.030  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 0                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.0000 100.0000 1 1  #  Position x, y
#  3) 20.0947     1          #  Integrated magnitude
#  4) 2.1433      1          #  R_e (effective radius)   [pix]
#  5) 5.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.4657      1          #  Axis ratio (b/a)
# 10) 202.8700    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.0000 100.0000 1 1  #  Position x, y
#  3) 20.0947     1          #  Integrated magnitude
#  4) 4.2867      1          #  R_e (effective radius)   [pix]
#  5) 1.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.4657      1          #  Axis ratio (b/a)
# 10) 202.8700    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
# ================================================================================
# Initial parameters:
#  sersic    : (  100.00,   100.00)   20.09      2.14    5.00    0.47    22.87
#  sersic    : ( {100.00}, {100.00})  20.09      4.29    1.00    0.47   {22.87}
# ================================================================================
#
# Iteration : 1     Chi2nu: 1.999e+02     dChi2/Chi2: -1.26e+20   alamda: 1e-03
#  sersic    : (   99.97,   100.12)   20.64      4.57    9.41    0.51    21.83
#  sersic    : (  {99.97}, {100.12})  20.99      4.14    1.25    0.47   {21.83}
# COUNTDOWN = 99
#
# Iteration : 2     Chi2nu: 5.217e+01     dChi2/Chi2: -2.83e+00   alamda: 1e-04
#  sersic    : (   99.92,   100.37)   20.12     17.29  *10.00*   0.94    19.26
#  sersic    : (  {99.92}, {100.37})  22.12      5.62    1.57    0.72   {19.26}
# COUNTDOWN = 98
#
# Iteration : 3     Chi2nu: 3.013e+01     dChi2/Chi2: -7.31e-01   alamda: 1e-05
#  sersic    : (   99.89,   100.93)   20.59     28.75    6.70    0.63    -9.17
#  sersic    : (  {99.89}, {100.93})  20.30     12.80    3.00    0.70   {-9.17}
# COUNTDOWN = 97
#
# Iteration : 4     Chi2nu: 3.013e+01     dChi2/Chi2: -3.81e-08   alamda: 1e-04
#  sersic    : (   99.89,   100.93)   20.59     28.75    6.70    0.63    -9.17
#  sersic    : (  {99.89}, {100.93})  20.30     12.80    3.00    0.70   {-9.17}
# COUNTDOWN = 10
#
# Iteration : 5     Chi2nu: 3.013e+01     dChi2/Chi2: -3.81e-08   alamda: 1e-03
#  sersic    : (   99.89,   100.93)   20.59     28.75    6.70    0.63    -9.17
#  sersic    : (  {99.89}, {100.93})  20.30     12.80    3.00    0.70   {-9.17}
# COUNTDOWN = 9
#
# Iteration : 6     Chi2nu: 3.013e+01     dChi2/Chi2: -3.81e-08   alamda: 1e-02
#  sersic    : (   99.89,   100.93)   20.59     28.75    6.70    0.63    -9.17
#  sersic    : (  {99.89}, {100.93})  20.30     12.80    3.00    0.70   {-9.17}
# COUNTDOWN = 8
#
# Iteration : 7     Chi2nu: 3.013e+01     dChi2/Chi2: -3.81e-08   alamda: 1e-01
#  sersic    : (   99.89,   100.93)   20.59     28.75    6.70    0.63    -9.17
#  sersic    : (  {99.89}, {100.93})  20.30     12.80    3.00    0.70   {-9.17}
# COUNTDOWN = 7
#
# Iteration : 8     Chi2nu: 1.023e+01     dChi2/Chi2: -1.94e+00   alamda: 1e-02
#  sersic    : (   99.90,   101.64)   21.10     38.14    5.28    0.69    -9.26
#  sersic    : (  {99.90}, {101.64})  20.50     11.69    2.01    0.72   {-9.26}
# COUNTDOWN = 92
#
# Iteration : 9     Chi2nu: 5.326e+00     dChi2/Chi2: -9.21e-01   alamda: 1e-03
#  sersic    : (   99.95,   103.29)   21.65     45.74    2.00    0.52   -10.94
#  sersic    : (  {99.95}, {103.29})  20.43      9.15    1.90    0.74  {-10.94}
# COUNTDOWN = 91
#
# Iteration : 10    Chi2nu: 5.326e+00     dChi2/Chi2: 4.83e-09    alamda: 1e-02
#  sersic    : (   99.95,   103.29)   21.65     45.74    2.00    0.52   -10.94
#  sersic    : (  {99.95}, {103.29})  20.43      9.15    1.90    0.74  {-10.94}
# COUNTDOWN = 10
#
# Iteration : 11    Chi2nu: 3.425e+00     dChi2/Chi2: -5.55e-01   alamda: 1e-03
#  sersic    : (   99.99,   104.07)   21.27     43.83  *10.00*   0.70   -15.08
#  sersic    : (  {99.99}, {104.07})  20.32     10.96    3.00    0.99  {-15.08}
# COUNTDOWN = 89
#
# Iteration : 12    Chi2nu: 3.425e+00     dChi2/Chi2: -4.40e-08   alamda: 1e-02
#  sersic    : (   99.99,   104.07)   21.27     43.83  *10.00*   0.70   -15.08
#  sersic    : (  {99.99}, {104.07})  20.32     10.96    3.00    0.99  {-15.08}
# COUNTDOWN = 10
#
# Iteration : 13    Chi2nu: 3.297e+00     dChi2/Chi2: -3.88e-02   alamda: 1e-03
#  sersic    : (  100.01,   104.25)   21.27     23.08  *10.00*   0.67   -45.57
#  sersic    : ( {100.01}, {104.25})  20.36     11.02    2.72    0.71  {-45.57}
# COUNTDOWN = 87
#
# Iteration : 14    Chi2nu: 3.297e+00     dChi2/Chi2: 2.13e-08    alamda: 1e-02
#  sersic    : (  100.01,   104.25)   21.27     23.08  *10.00*   0.67   -45.57
#  sersic    : ( {100.01}, {104.25})  20.36     11.02    2.72    0.71  {-45.57}
# COUNTDOWN = 10
#
# Iteration : 15    Chi2nu: 3.297e+00     dChi2/Chi2: 2.13e-08    alamda: 1e-01
#  sersic    : (  100.01,   104.25)   21.27     23.08  *10.00*   0.67   -45.57
#  sersic    : ( {100.01}, {104.25})  20.36     11.02    2.72    0.71  {-45.57}
# COUNTDOWN = 9
#
# Iteration : 16    Chi2nu: 2.923e+00     dChi2/Chi2: -1.28e-01   alamda: 1e-02
#  sersic    : (  100.01,   104.28)   21.36     12.73  *10.00*   0.89   -44.58
#  sersic    : ( {100.01}, {104.28})  20.39     10.66    2.65    0.75  {-44.58}
# COUNTDOWN = 84
#
# Iteration : 17    Chi2nu: 2.923e+00     dChi2/Chi2: 6.71e-09    alamda: 1e-01
#  sersic    : (  100.01,   104.28)   21.36     12.73  *10.00*   0.89   -44.58
#  sersic    : ( {100.01}, {104.28})  20.39     10.66    2.65    0.75  {-44.58}
# COUNTDOWN = 10
#
# Iteration : 18    Chi2nu: 2.824e+00     dChi2/Chi2: -3.51e-02   alamda: 1e-02
#  sersic    : (  100.02,   104.29)   21.39      7.94  *10.00*   0.83   -43.34
#  sersic    : ( {100.02}, {104.29})  20.43     10.49    2.62    0.77  {-43.34}
# COUNTDOWN = 82
#
# Iteration : 19    Chi2nu: 2.824e+00     dChi2/Chi2: 1.02e-08    alamda: 1e-01
#  sersic    : (  100.02,   104.29)   21.39      7.94  *10.00*   0.83   -43.34
#  sersic    : ( {100.02}, {104.29})  20.43     10.49    2.62    0.77  {-43.34}
# COUNTDOWN = 10
#
# Iteration : 20    Chi2nu: 2.725e+00     dChi2/Chi2: -3.61e-02   alamda: 1e-02
#  sersic    : (  100.02,   104.30)   21.42      5.44  *10.00*   0.98   -42.39
#  sersic    : ( {100.02}, {104.30})  20.47     10.60    2.58    0.81  {-42.39}
# COUNTDOWN = 80
#
# Iteration : 21    Chi2nu: 2.725e+00     dChi2/Chi2: -4.88e-09   alamda: 1e-01
#  sersic    : (  100.02,   104.30)   21.42      5.44  *10.00*   0.98   -42.39
#  sersic    : ( {100.02}, {104.30})  20.47     10.60    2.58    0.81  {-42.39}
# COUNTDOWN = 10
#
# Iteration : 22    Chi2nu: 2.709e+00     dChi2/Chi2: -6.10e-03   alamda: 1e-02
#  sersic    : (  100.02,   104.30)   21.42      4.42    7.94    1.00   -41.06
#  sersic    : ( {100.02}, {104.30})  20.50     10.90    2.48    0.82  {-41.06}
# COUNTDOWN = 78
#
# Iteration : 23    Chi2nu: 2.709e+00     dChi2/Chi2: 4.31e-10    alamda: 1e-01
#  sersic    : (  100.02,   104.30)   21.42      4.42    7.94    1.00   -41.06
#  sersic    : ( {100.02}, {104.30})  20.50     10.90    2.48    0.82  {-41.06}
# COUNTDOWN = 10
#
# Iteration : 24    Chi2nu: 2.693e+00     dChi2/Chi2: -6.08e-03   alamda: 1e-02
#  sersic    : (  100.02,   104.30)   21.40      3.61    6.47    0.94   -39.83
#  sersic    : ( {100.02}, {104.30})  20.53     11.39    2.34    0.83  {-39.83}
# COUNTDOWN = 76
#
# Iteration : 25    Chi2nu: 2.693e+00     dChi2/Chi2: 6.20e-09    alamda: 1e-01
#  sersic    : (  100.02,   104.30)   21.40      3.61    6.47    0.94   -39.83
#  sersic    : ( {100.02}, {104.30})  20.53     11.39    2.34    0.83  {-39.83}
# COUNTDOWN = 10
#
# Iteration : 26    Chi2nu: 2.665e+00     dChi2/Chi2: -1.03e-02   alamda: 1e-02
#  sersic    : (  100.02,   104.30)   21.39      2.89    4.81    0.88   -38.94
#  sersic    : ( {100.02}, {104.30})  20.57     12.17    2.12    0.85  {-38.94}
# COUNTDOWN = 74
#
# Iteration : 27    Chi2nu: 2.665e+00     dChi2/Chi2: 2.04e-09    alamda: 1e-01
#  sersic    : (  100.02,   104.30)   21.39      2.89    4.81    0.88   -38.94
#  sersic    : ( {100.02}, {104.30})  20.57     12.17    2.12    0.85  {-38.94}
# COUNTDOWN = 10
#
# Iteration : 28    Chi2nu: 2.620e+00     dChi2/Chi2: -1.72e-02   alamda: 1e-02
#  sersic    : (  100.02,   104.30)   21.37      2.65    3.28    0.85   -38.37
#  sersic    : ( {100.02}, {104.30})  20.60     13.26    1.71    0.86  {-38.37}
# COUNTDOWN = 72
#
# Iteration : 29    Chi2nu: 2.620e+00     dChi2/Chi2: 3.27e-09    alamda: 1e-01
#  sersic    : (  100.02,   104.30)   21.37      2.65    3.28    0.85   -38.37
#  sersic    : ( {100.02}, {104.30})  20.60     13.26    1.71    0.86  {-38.37}
# COUNTDOWN = 10
#
# Iteration : 30    Chi2nu: 2.620e+00     dChi2/Chi2: 3.27e-09    alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.37      2.65    3.28    0.85   -38.37
#  sersic    : ( {100.02}, {104.30})  20.60     13.26    1.71    0.86  {-38.37}
# COUNTDOWN = 9
#
# Iteration : 31    Chi2nu: 2.620e+00     dChi2/Chi2: 3.27e-09    alamda: 1e+01
#  sersic    : (  100.02,   104.30)   21.37      2.65    3.28    0.85   -38.37
#  sersic    : ( {100.02}, {104.30})  20.60     13.26    1.71    0.86  {-38.37}
# COUNTDOWN = 8
#
# Iteration : 32    Chi2nu: 2.617e+00     dChi2/Chi2: -1.05e-03   alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.37      2.63    3.30    0.85   -38.33
#  sersic    : ( {100.02}, {104.30})  20.60     13.13    1.70    0.86  {-38.33}
# COUNTDOWN = 68
#
# Iteration : 33    Chi2nu: 2.617e+00     dChi2/Chi2: -1.02e-08   alamda: 1e+01
#  sersic    : (  100.02,   104.30)   21.37      2.63    3.30    0.85   -38.33
#  sersic    : ( {100.02}, {104.30})  20.60     13.13    1.70    0.86  {-38.33}
# COUNTDOWN = 10
#
# Iteration : 34    Chi2nu: 2.616e+00     dChi2/Chi2: -4.82e-04   alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.37      2.60    3.31    0.85   -38.30
#  sersic    : ( {100.02}, {104.30})  20.60     13.01    1.70    0.86  {-38.30}
# COUNTDOWN = 66
#
# Iteration : 35    Chi2nu: 2.611e+00     dChi2/Chi2: -1.92e-03   alamda: 1e-01
#  sersic    : (  100.02,   104.30)   21.37      2.63    3.34    0.84   -38.16
#  sersic    : ( {100.02}, {104.30})  20.60     13.16    1.62    0.86  {-38.16}
# COUNTDOWN = 65
#
# Iteration : 36    Chi2nu: 2.611e+00     dChi2/Chi2: -4.22e-09   alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.37      2.63    3.34    0.84   -38.16
#  sersic    : ( {100.02}, {104.30})  20.60     13.16    1.62    0.86  {-38.16}
# COUNTDOWN = 10
#
# Iteration : 37    Chi2nu: 2.611e+00     dChi2/Chi2: -4.22e-09   alamda: 1e+01
#  sersic    : (  100.02,   104.30)   21.37      2.63    3.34    0.84   -38.16
#  sersic    : ( {100.02}, {104.30})  20.60     13.16    1.62    0.86  {-38.16}
# COUNTDOWN = 9
#
# Iteration : 38    Chi2nu: 2.609e+00     dChi2/Chi2: -7.89e-04   alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.37      2.60    3.34    0.84   -38.13
#  sersic    : ( {100.02}, {104.30})  20.61     13.02    1.62    0.86  {-38.13}
# COUNTDOWN = 62
#
# Iteration : 39    Chi2nu: 2.609e+00     dChi2/Chi2: -4.60e-09   alamda: 1e+01
#  sersic    : (  100.02,   104.30)   21.37      2.60    3.34    0.84   -38.13
#  sersic    : ( {100.02}, {104.30})  20.61     13.02    1.62    0.86  {-38.13}
# COUNTDOWN = 10
#
# Iteration : 40    Chi2nu: 2.608e+00     dChi2/Chi2: -1.50e-04   alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.37      2.58    3.35    0.84   -38.11
#  sersic    : ( {100.02}, {104.30})  20.61     12.90    1.61    0.86  {-38.11}
# COUNTDOWN = 60
#
# Iteration : 41    Chi2nu: 2.605e+00     dChi2/Chi2: -1.37e-03   alamda: 1e-01
#  sersic    : (  100.02,   104.30)   21.36      2.62    3.31    0.84   -38.07
#  sersic    : ( {100.02}, {104.30})  20.61     13.08    1.55    0.86  {-38.07}
# COUNTDOWN = 59
#
# Iteration : 42    Chi2nu: 2.605e+00     dChi2/Chi2: 2.71e-08    alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.36      2.62    3.31    0.84   -38.07
#  sersic    : ( {100.02}, {104.30})  20.61     13.08    1.55    0.86  {-38.07}
# COUNTDOWN = 10
#
# Iteration : 43    Chi2nu: 2.605e+00     dChi2/Chi2: 2.71e-08    alamda: 1e+01
#  sersic    : (  100.02,   104.30)   21.36      2.62    3.31    0.84   -38.07
#  sersic    : ( {100.02}, {104.30})  20.61     13.08    1.55    0.86  {-38.07}
# COUNTDOWN = 9
#
# Iteration : 44    Chi2nu: 2.603e+00     dChi2/Chi2: -6.64e-04   alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.36      2.59    3.32    0.83   -38.05
#  sersic    : ( {100.02}, {104.30})  20.62     12.94    1.55    0.86  {-38.05}
# COUNTDOWN = 56
#
# Iteration : 45    Chi2nu: 2.601e+00     dChi2/Chi2: -8.03e-04   alamda: 1e-01
#  sersic    : (  100.02,   104.30)   21.36      2.62    3.25    0.83   -38.01
#  sersic    : ( {100.02}, {104.30})  20.62     13.11    1.50    0.86  {-38.01}
# COUNTDOWN = 55
#
# Iteration : 46    Chi2nu: 2.601e+00     dChi2/Chi2: -1.20e-08   alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.36      2.62    3.25    0.83   -38.01
#  sersic    : ( {100.02}, {104.30})  20.62     13.11    1.50    0.86  {-38.01}
# COUNTDOWN = 10
#
# Iteration : 47    Chi2nu: 2.601e+00     dChi2/Chi2: -1.20e-08   alamda: 1e+01
#  sersic    : (  100.02,   104.30)   21.36      2.62    3.25    0.83   -38.01
#  sersic    : ( {100.02}, {104.30})  20.62     13.11    1.50    0.86  {-38.01}
# COUNTDOWN = 9
#
# Iteration : 48    Chi2nu: 2.599e+00     dChi2/Chi2: -8.83e-04   alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.36      2.59    3.25    0.83   -38.00
#  sersic    : ( {100.02}, {104.30})  20.62     12.95    1.50    0.86  {-38.00}
# COUNTDOWN = 52
#
# Iteration : 49    Chi2nu: 2.597e+00     dChi2/Chi2: -6.98e-04   alamda: 1e-01
#  sersic    : (  100.02,   104.30)   21.35      2.63    3.18    0.83   -37.99
#  sersic    : ( {100.02}, {104.30})  20.63     13.14    1.45    0.86  {-37.99}
# COUNTDOWN = 51
#
# Iteration : 50    Chi2nu: 2.597e+00     dChi2/Chi2: -5.64e-09   alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.35      2.63    3.18    0.83   -37.99
#  sersic    : ( {100.02}, {104.30})  20.63     13.14    1.45    0.86  {-37.99}
# COUNTDOWN = 10
#
# Iteration : 51    Chi2nu: 2.597e+00     dChi2/Chi2: -5.64e-09   alamda: 1e+01
#  sersic    : (  100.02,   104.30)   21.35      2.63    3.18    0.83   -37.99
#  sersic    : ( {100.02}, {104.30})  20.63     13.14    1.45    0.86  {-37.99}
# COUNTDOWN = 9
#
# Iteration : 52    Chi2nu: 2.594e+00     dChi2/Chi2: -9.95e-04   alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.35      2.59    3.18    0.83   -37.98
#  sersic    : ( {100.02}, {104.30})  20.63     12.97    1.45    0.86  {-37.98}
# COUNTDOWN = 48
#
# Iteration : 53    Chi2nu: 2.593e+00     dChi2/Chi2: -6.69e-04   alamda: 1e-01
#  sersic    : (  100.02,   104.30)   21.34      2.63    3.11    0.83   -37.99
#  sersic    : ( {100.02}, {104.30})  20.64     13.17    1.40    0.86  {-37.99}
# COUNTDOWN = 47
#
# Iteration : 54    Chi2nu: 2.593e+00     dChi2/Chi2: 1.86e-08    alamda: 1e+00
#  sersic    : (  100.02,   104.30)   21.34      2.63    3.11    0.83   -37.99
#  sersic    : ( {100.02}, {104.30})  20.64     13.17    1.40    0.86  {-37.99}
# COUNTDOWN = 10
#
# Iteration : 55    Chi2nu: 2.593e+00     dChi2/Chi2: 1.86e-08    alamda: 1e+01
#  sersic    : (  100.02,   104.30)   21.34      2.63    3.11    0.83   -37.99
# ...
#  sersic    : (   99.68,   103.69)   19.98      6.90    4.31    0.92   -30.44
#  sersic    : (  {99.68}, {103.69})  21.61     15.08    0.40    0.71  {-30.44}
# COUNTDOWN = 10
#
# Iteration : 42    Chi2nu: 1.596e+01     dChi2/Chi2: -6.89e-04   alamda: 1e-02
#  sersic    : (   99.68,   103.69)   19.98      6.88    4.32    0.91   -30.59
#  sersic    : (  {99.68}, {103.69})  21.61     15.06    0.40    0.70  {-30.59}
# COUNTDOWN = 58
#
# Iteration : 43    Chi2nu: 1.596e+01     dChi2/Chi2: -9.43e-09   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   19.98      6.88    4.32    0.91   -30.59
#  sersic    : (  {99.68}, {103.69})  21.61     15.06    0.40    0.70  {-30.59}
# COUNTDOWN = 10
#
# Iteration : 44    Chi2nu: 1.596e+01     dChi2/Chi2: -1.25e-04   alamda: 1e-02
#  sersic    : (   99.68,   103.69)   19.99      6.87    4.32    0.92   -30.71
#  sersic    : (  {99.68}, {103.69})  21.60     15.06    0.40    0.71  {-30.71}
# COUNTDOWN = 56
#
# Iteration : 45    Chi2nu: 1.596e+01     dChi2/Chi2: -2.33e-08   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   19.99      6.87    4.32    0.92   -30.71
#  sersic    : (  {99.68}, {103.69})  21.60     15.06    0.40    0.71  {-30.71}
# COUNTDOWN = 10
#
# Iteration : 46    Chi2nu: 1.595e+01     dChi2/Chi2: -5.49e-04   alamda: 1e-02
#  sersic    : (   99.68,   103.69)   19.99      6.86    4.33    0.91   -30.81
#  sersic    : (  {99.68}, {103.69})  21.59     15.04    0.40    0.70  {-30.81}
# COUNTDOWN = 54
#
# Iteration : 47    Chi2nu: 1.595e+01     dChi2/Chi2: -2.21e-08   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   19.99      6.86    4.33    0.91   -30.81
#  sersic    : (  {99.68}, {103.69})  21.59     15.04    0.40    0.70  {-30.81}
# COUNTDOWN = 10
#
# Iteration : 48    Chi2nu: 1.595e+01     dChi2/Chi2: -2.21e-08   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   19.99      6.86    4.33    0.91   -30.81
#  sersic    : (  {99.68}, {103.69})  21.59     15.04    0.40    0.70  {-30.81}
# COUNTDOWN = 9
#
# Iteration : 49    Chi2nu: 1.593e+01     dChi2/Chi2: -1.39e-03   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   19.99      6.88    4.31    0.91   -30.85
#  sersic    : (  {99.68}, {103.69})  21.58     14.96    0.40    0.70  {-30.85}
# COUNTDOWN = 51
#
# Iteration : 50    Chi2nu: 1.593e+01     dChi2/Chi2: 3.48e-08    alamda: 1e+00
#  sersic    : (   99.68,   103.69)   19.99      6.88    4.31    0.91   -30.85
#  sersic    : (  {99.68}, {103.69})  21.58     14.96    0.40    0.70  {-30.85}
# COUNTDOWN = 10
#
# Iteration : 51    Chi2nu: 1.592e+01     dChi2/Chi2: -4.90e-04   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   19.99      6.89    4.31    0.91   -30.89
#  sersic    : (  {99.68}, {103.69})  21.57     14.90    0.40    0.70  {-30.89}
# COUNTDOWN = 49
#
# Iteration : 52    Chi2nu: 1.592e+01     dChi2/Chi2: 1.33e-08    alamda: 1e+00
#  sersic    : (   99.68,   103.69)   19.99      6.89    4.31    0.91   -30.89
#  sersic    : (  {99.68}, {103.69})  21.57     14.90    0.40    0.70  {-30.89}
# COUNTDOWN = 10
#
# Iteration : 53    Chi2nu: 1.592e+01     dChi2/Chi2: -4.60e-04   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   19.99      6.89    4.32    0.91   -30.93
#  sersic    : (  {99.68}, {103.69})  21.57     14.87    0.40    0.70  {-30.93}
# COUNTDOWN = 47
#
# Iteration : 54    Chi2nu: 1.592e+01     dChi2/Chi2: -4.08e-08   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   19.99      6.89    4.32    0.91   -30.93
#  sersic    : (  {99.68}, {103.69})  21.57     14.87    0.40    0.70  {-30.93}
# COUNTDOWN = 10
#
# Iteration : 55    Chi2nu: 1.591e+01     dChi2/Chi2: -1.92e-04   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   19.99      6.89    4.33    0.91   -30.97
#  sersic    : (  {99.68}, {103.69})  21.56     14.84    0.40    0.70  {-30.97}
# COUNTDOWN = 45
#
# Iteration : 56    Chi2nu: 1.591e+01     dChi2/Chi2: -1.32e-08   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   19.99      6.89    4.33    0.91   -30.97
#  sersic    : (  {99.68}, {103.69})  21.56     14.84    0.40    0.70  {-30.97}
# COUNTDOWN = 10
#
# Iteration : 57    Chi2nu: 1.591e+01     dChi2/Chi2: -3.14e-04   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   19.99      6.89    4.33    0.91   -31.00
#  sersic    : (  {99.68}, {103.69})  21.56     14.83    0.40    0.70  {-31.00}
# COUNTDOWN = 43
#
# Iteration : 58    Chi2nu: 1.591e+01     dChi2/Chi2: 1.68e-08    alamda: 1e+00
#  sersic    : (   99.68,   103.69)   19.99      6.89    4.33    0.91   -31.00
#  sersic    : (  {99.68}, {103.69})  21.56     14.83    0.40    0.70  {-31.00}
# COUNTDOWN = 10
#
# Iteration : 59    Chi2nu: 1.591e+01     dChi2/Chi2: -1.16e-04   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   19.99      6.88    4.34    0.91   -31.03
#  sersic    : (  {99.68}, {103.69})  21.55     14.81    0.40    0.70  {-31.03}
# COUNTDOWN = 41
#
# Iteration : 60    Chi2nu: 1.591e+01     dChi2/Chi2: -2.94e-08   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   19.99      6.88    4.34    0.91   -31.03
#  sersic    : (  {99.68}, {103.69})  21.55     14.81    0.40    0.70  {-31.03}
# COUNTDOWN = 10
#
# Iteration : 61    Chi2nu: 1.590e+01     dChi2/Chi2: -2.64e-04   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   20.00      6.88    4.35    0.92   -31.06
#  sersic    : (  {99.68}, {103.69})  21.55     14.81    0.40    0.70  {-31.06}
# COUNTDOWN = 39
#
# Iteration : 62    Chi2nu: 1.590e+01     dChi2/Chi2: 2.70e-09    alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.88    4.35    0.92   -31.06
#  sersic    : (  {99.68}, {103.69})  21.55     14.81    0.40    0.70  {-31.06}
# COUNTDOWN = 10
#
# Iteration : 63    Chi2nu: 1.590e+01     dChi2/Chi2: -7.57e-05   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   20.00      6.87    4.36    0.91   -31.08
#  sersic    : (  {99.68}, {103.69})  21.54     14.79    0.40    0.70  {-31.08}
# COUNTDOWN = 37
#
# Iteration : 64    Chi2nu: 1.590e+01     dChi2/Chi2: -1.14e-08   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.87    4.36    0.91   -31.08
#  sersic    : (  {99.68}, {103.69})  21.54     14.79    0.40    0.70  {-31.08}
# COUNTDOWN = 10
#
# Iteration : 65    Chi2nu: 1.590e+01     dChi2/Chi2: -2.36e-04   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   20.00      6.87    4.37    0.92   -31.11
#  sersic    : (  {99.68}, {103.69})  21.54     14.79    0.40    0.70  {-31.11}
# COUNTDOWN = 35
#
# Iteration : 66    Chi2nu: 1.590e+01     dChi2/Chi2: 2.21e-08    alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.87    4.37    0.92   -31.11
#  sersic    : (  {99.68}, {103.69})  21.54     14.79    0.40    0.70  {-31.11}
# COUNTDOWN = 10
#
# Iteration : 67    Chi2nu: 1.590e+01     dChi2/Chi2: -4.81e-05   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   20.00      6.86    4.38    0.91   -31.12
#  sersic    : (  {99.68}, {103.69})  21.53     14.77    0.40    0.70  {-31.12}
# COUNTDOWN = 33
#
# Iteration : 68    Chi2nu: 1.590e+01     dChi2/Chi2: -3.88e-08   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.86    4.38    0.91   -31.12
#  sersic    : (  {99.68}, {103.69})  21.53     14.77    0.40    0.70  {-31.12}
# COUNTDOWN = 10
#
# Iteration : 69    Chi2nu: 1.589e+01     dChi2/Chi2: -2.15e-04   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   20.00      6.86    4.38    0.92   -31.14
#  sersic    : (  {99.68}, {103.69})  21.53     14.77    0.40    0.70  {-31.14}
# COUNTDOWN = 31
#
# Iteration : 70    Chi2nu: 1.589e+01     dChi2/Chi2: -4.72e-08   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.86    4.38    0.92   -31.14
#  sersic    : (  {99.68}, {103.69})  21.53     14.77    0.40    0.70  {-31.14}
# COUNTDOWN = 10
#
# Iteration : 71    Chi2nu: 1.589e+01     dChi2/Chi2: -2.89e-05   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   20.00      6.85    4.39    0.91   -31.16
#  sersic    : (  {99.68}, {103.69})  21.52     14.76    0.40    0.70  {-31.16}
# COUNTDOWN = 9
#
# Iteration : 72    Chi2nu: 1.589e+01     dChi2/Chi2: 1.99e-08    alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.85    4.39    0.91   -31.16
#  sersic    : (  {99.68}, {103.69})  21.52     14.76    0.40    0.70  {-31.16}
# COUNTDOWN = 8
#
# Iteration : 73    Chi2nu: 1.589e+01     dChi2/Chi2: -1.98e-04   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   20.00      6.84    4.39    0.92   -31.17
#  sersic    : (  {99.68}, {103.69})  21.52     14.76    0.40    0.71  {-31.17}
# COUNTDOWN = 27
#
# Iteration : 74    Chi2nu: 1.589e+01     dChi2/Chi2: -9.67e-09   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.84    4.39    0.92   -31.17
#  sersic    : (  {99.68}, {103.69})  21.52     14.76    0.40    0.71  {-31.17}
# COUNTDOWN = 10
#
# Iteration : 75    Chi2nu: 1.589e+01     dChi2/Chi2: -1.24e-05   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.40    0.91   -31.18
#  sersic    : (  {99.68}, {103.69})  21.52     14.75    0.40    0.70  {-31.18}
# COUNTDOWN = 9
#
# Iteration : 76    Chi2nu: 1.589e+01     dChi2/Chi2: -3.47e-08   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.40    0.91   -31.18
#  sersic    : (  {99.68}, {103.69})  21.52     14.75    0.40    0.70  {-31.18}
# COUNTDOWN = 8
#
# Iteration : 77    Chi2nu: 1.589e+01     dChi2/Chi2: -1.84e-04   alamda: 1e-01
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.40    0.92   -31.20
#  sersic    : (  {99.68}, {103.69})  21.51     14.75    0.40    0.71  {-31.20}
# COUNTDOWN = 23
#
# Iteration : 78    Chi2nu: 1.589e+01     dChi2/Chi2: 5.41e-09    alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.40    0.92   -31.20
#  sersic    : (  {99.68}, {103.69})  21.51     14.75    0.40    0.71  {-31.20}
# COUNTDOWN = 10
#
# Iteration : 79    Chi2nu: 1.589e+01     dChi2/Chi2: 5.41e-09    alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.40    0.92   -31.20
#  sersic    : (  {99.68}, {103.69})  21.51     14.75    0.40    0.71  {-31.20}
# COUNTDOWN = 9
#
# Iteration : 80    Chi2nu: 1.588e+01     dChi2/Chi2: -1.04e-04   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.40    0.92   -31.20
#  sersic    : (  {99.68}, {103.69})  21.51     14.74    0.40    0.70  {-31.20}
# COUNTDOWN = 20
#
# Iteration : 81    Chi2nu: 1.588e+01     dChi2/Chi2: -1.06e-08   alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.40    0.92   -31.20
#  sersic    : (  {99.68}, {103.69})  21.51     14.74    0.40    0.70  {-31.20}
# COUNTDOWN = 10
#
# Iteration : 82    Chi2nu: 1.588e+01     dChi2/Chi2: -5.82e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.40    0.91   -31.20
#  sersic    : (  {99.68}, {103.69})  21.51     14.73    0.40    0.70  {-31.20}
# COUNTDOWN = 18
#
# Iteration : 83    Chi2nu: 1.588e+01     dChi2/Chi2: 2.34e-08    alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.40    0.91   -31.20
#  sersic    : (  {99.68}, {103.69})  21.51     14.73    0.40    0.70  {-31.20}
# COUNTDOWN = 10
#
# Iteration : 84    Chi2nu: 1.588e+01     dChi2/Chi2: -3.39e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.39    0.91   -31.20
#  sersic    : (  {99.68}, {103.69})  21.51     14.72    0.40    0.70  {-31.20}
# COUNTDOWN = 16
#
# Iteration : 85    Chi2nu: 1.588e+01     dChi2/Chi2: 3.25e-08    alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.39    0.91   -31.20
#  sersic    : (  {99.68}, {103.69})  21.51     14.72    0.40    0.70  {-31.20}
# COUNTDOWN = 10
#
# Iteration : 86    Chi2nu: 1.588e+01     dChi2/Chi2: -5.37e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.39    0.91   -31.21
#  sersic    : (  {99.68}, {103.69})  21.51     14.71    0.40    0.70  {-31.21}
# COUNTDOWN = 14
#
# Iteration : 87    Chi2nu: 1.588e+01     dChi2/Chi2: 6.38e-09    alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.39    0.91   -31.21
#  sersic    : (  {99.68}, {103.69})  21.51     14.71    0.40    0.70  {-31.21}
# COUNTDOWN = 10
#
# Iteration : 88    Chi2nu: 1.588e+01     dChi2/Chi2: -4.30e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.39    0.92   -31.21
#  sersic    : (  {99.68}, {103.69})  21.51     14.71    0.40    0.70  {-31.21}
# COUNTDOWN = 12
#
# Iteration : 89    Chi2nu: 1.588e+01     dChi2/Chi2: -4.51e-08   alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.39    0.92   -31.21
#  sersic    : (  {99.68}, {103.69})  21.51     14.71    0.40    0.70  {-31.21}
# COUNTDOWN = 10
#
# Iteration : 90    Chi2nu: 1.588e+01     dChi2/Chi2: -1.99e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.39    0.91   -31.21
#  sersic    : (  {99.68}, {103.69})  21.51     14.70    0.40    0.70  {-31.21}
# COUNTDOWN = 9
#
# Iteration : 91    Chi2nu: 1.588e+01     dChi2/Chi2: -1.16e-08   alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.00      6.83    4.39    0.91   -31.21
#  sersic    : (  {99.68}, {103.69})  21.51     14.70    0.40    0.70  {-31.21}
# COUNTDOWN = 8
#
# Iteration : 92    Chi2nu: 1.588e+01     dChi2/Chi2: -3.84e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.84    4.39    0.91   -31.21
#  sersic    : (  {99.68}, {103.69})  21.51     14.69    0.40    0.70  {-31.21}
# COUNTDOWN = 8
#
# Iteration : 93    Chi2nu: 1.588e+01     dChi2/Chi2: 1.75e-08    alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.00      6.84    4.39    0.91   -31.21
#  sersic    : (  {99.68}, {103.69})  21.51     14.69    0.40    0.70  {-31.21}
# COUNTDOWN = 10
#
# Iteration : 94    Chi2nu: 1.588e+01     dChi2/Chi2: -1.38e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.00      6.84    4.39    0.91   -31.21
#  sersic    : (  {99.68}, {103.69})  21.51     14.69    0.40    0.70  {-31.21}
# COUNTDOWN = 9
#
# Iteration : 95    Chi2nu: 1.588e+01     dChi2/Chi2: -2.19e-08   alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.00      6.84    4.39    0.91   -31.21
#  sersic    : (  {99.68}, {103.69})  21.51     14.69    0.40    0.70  {-31.21}
# COUNTDOWN = 8
#
# Iteration : 96    Chi2nu: 1.588e+01     dChi2/Chi2: -3.44e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.01      6.84    4.39    0.91   -31.22
#  sersic    : (  {99.68}, {103.69})  21.51     14.68    0.40    0.70  {-31.22}
# COUNTDOWN = 4
#
# Iteration : 97    Chi2nu: 1.588e+01     dChi2/Chi2: 4.11e-08    alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.01      6.84    4.39    0.91   -31.22
#  sersic    : (  {99.68}, {103.69})  21.51     14.68    0.40    0.70  {-31.22}
# COUNTDOWN = 10
#
# Iteration : 98    Chi2nu: 1.588e+01     dChi2/Chi2: -2.97e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.01      6.84    4.39    0.92   -31.22
#  sersic    : (  {99.68}, {103.69})  21.50     14.68    0.40    0.70  {-31.22}
# COUNTDOWN = 9
#
# Iteration : 99    Chi2nu: 1.588e+01     dChi2/Chi2: -3.77e-08   alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.01      6.84    4.39    0.92   -31.22
#  sersic    : (  {99.68}, {103.69})  21.50     14.68    0.40    0.70  {-31.22}
# COUNTDOWN = 8
#
# Iteration : 100    Chi2nu: 1.588e+01     dChi2/Chi2: -1.12e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.01      6.84    4.39    0.91   -31.22
#  sersic    : (  {99.68}, {103.69})  21.50     14.68    0.40    0.70  {-31.22}
# COUNTDOWN = 7
#
# Iteration : 101    Chi2nu: 1.588e+01     dChi2/Chi2: -1.55e-09   alamda: 1e+01
#  sersic    : (   99.68,   103.69)   20.01      6.84    4.39    0.91   -31.22
#  sersic    : (  {99.68}, {103.69})  21.50     14.68    0.40    0.70  {-31.22}
# COUNTDOWN = 6
#
# Iteration : 102    Chi2nu: 1.588e+01     dChi2/Chi2: -2.83e-05   alamda: 1e+00
#  sersic    : (   99.68,   103.69)   20.01      6.84    4.39    0.92   -31.22
#  sersic    : (  {99.68}, {103.69})  21.50     14.67    0.40    0.70  {-31.22}
# COUNTDOWN = -2
# Running GALFIT...: 100%|██████████████████████████| 6/6 [03:52<00:00, 38.80s/it]
#  The fitting ended because the maximum number of iterations
#  has been reached, not necessarily because of convergence!
#
#
#
# Fit summary is now being saved into `fit.log'.

# %%
# save template images
for im in tqdm(images, desc='Getting templates...'):
    filt = im.split('_')[-4]
    gal.create_templates(obj_id, filt, num='02', oldnum='01', overwrite=True)
# Out:
# Getting templates...:  17%|███▊                   | 1/6 [00:00<00:03,  1.57it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_383_f090w_sci.fits      # Input data image (FITS file)
# B) obj_383_f090w_imgblock02.fits      # Output data image block
# C) obj_383_f090w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f090w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_383_f090w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.030  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 3                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 99.9926  104.2755 1 1  #  Position x, y
#  3) 21.0092     1          #  Integrated magnitude
#  4) 45.1889     1          #  R_e (effective radius)   [pix]
#  5) 10.0000     1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.9764      1          #  Axis ratio (b/a)
# 10) -45.0764    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 99.9926  104.2755 2 2  #  Position x, y
#  3) 21.9223     1          #  Integrated magnitude
#  4) 9.0378      1          #  R_e (effective radius)   [pix]
#  5) 2.4689      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.7511      1          #  Axis ratio (b/a)
# 10) -45.0764    2          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...:  33%|███████▋               | 2/6 [00:01<00:02,  1.58it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_383_f150w_sci.fits      # Input data image (FITS file)
# B) obj_383_f150w_imgblock02.fits      # Output data image block
# C) obj_383_f150w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f150w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_383_f150w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.030  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 3                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.0105 104.3073 1 1  #  Position x, y
#  3) 21.2270     1          #  Integrated magnitude
#  4) 2.7027      1          #  R_e (effective radius)   [pix]
#  5) 2.5578      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8177      1          #  Axis ratio (b/a)
# 10) -38.0672    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.0105 104.3073 2 2  #  Position x, y
#  3) 20.7547     1          #  Integrated magnitude
#  4) 13.5137     1          #  R_e (effective radius)   [pix]
#  5) 0.9849      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8621      1          #  Axis ratio (b/a)
# 10) -38.0672    2          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...:  50%|███████████▌           | 3/6 [00:01<00:01,  1.60it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_383_f200w_sci.fits      # Input data image (FITS file)
# B) obj_383_f200w_imgblock02.fits      # Output data image block
# C) obj_383_f200w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f200w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_383_f200w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.030  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 3                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 99.9521  104.2527 1 1  #  Position x, y
#  3) 20.0268     1          #  Integrated magnitude
#  4) 11.7018     1          #  R_e (effective radius)   [pix]
#  5) 2.8947      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8596      1          #  Axis ratio (b/a)
# 10) -36.6788    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 99.9521  104.2527 2 2  #  Position x, y
#  3) 21.4715     1          #  Integrated magnitude
#  4) 2.3650      1          #  R_e (effective radius)   [pix]
#  5) 2.7947      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.9237      1          #  Axis ratio (b/a)
# 10) -36.6788    2          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...:  67%|███████████████▎       | 4/6 [00:02<00:01,  1.60it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_383_f277w_sci.fits      # Input data image (FITS file)
# B) obj_383_f277w_imgblock02.fits      # Output data image block
# C) obj_383_f277w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f277w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_383_f277w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.030  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 3                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 99.6721  103.7153 1 1  #  Position x, y
#  3) 19.7408     1          #  Integrated magnitude
#  4) 6.4357      1          #  R_e (effective radius)   [pix]
#  5) 3.5506      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8990      1          #  Axis ratio (b/a)
# 10) -31.6553    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 99.6721  103.7153 2 2  #  Position x, y
#  3) 21.3394     1          #  Integrated magnitude
#  4) 15.5880     1          #  R_e (effective radius)   [pix]
#  5) 0.4000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.7735      1          #  Axis ratio (b/a)
# 10) -31.6553    2          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...:  83%|███████████████████▏   | 5/6 [00:03<00:00,  1.60it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_383_f356w_sci.fits      # Input data image (FITS file)
# B) obj_383_f356w_imgblock02.fits      # Output data image block
# C) obj_383_f356w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f356w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_383_f356w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.030  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 3                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 99.6534  103.7053 1 1  #  Position x, y
#  3) 20.4388     1          #  Integrated magnitude
#  4) 2.8827      1          #  R_e (effective radius)   [pix]
#  5) 2.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8756      1          #  Axis ratio (b/a)
# 10) -30.7517    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 99.6534  103.7053 2 2  #  Position x, y
#  3) 20.2534     1          #  Integrated magnitude
#  4) 14.4136     1          #  R_e (effective radius)   [pix]
#  5) 0.7453      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8563      1          #  Axis ratio (b/a)
# 10) -30.7517    2          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...: 100%|███████████████████████| 6/6 [00:03<00:00,  1.61it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_383_f444w_sci.fits      # Input data image (FITS file)
# B) obj_383_f444w_imgblock02.fits      # Output data image block
# C) obj_383_f444w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f444w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_383_f444w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.030  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 3                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 99.6760  103.6944 1 1  #  Position x, y
#  3) 20.0056     1          #  Integrated magnitude
#  4) 6.8373      1          #  R_e (effective radius)   [pix]
#  5) 4.3903      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.9152      1          #  Axis ratio (b/a)
# 10) -31.2216    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 99.6760  103.6944 2 2  #  Position x, y
#  3) 21.5031     1          #  Integrated magnitude
#  4) 14.6718     1          #  R_e (effective radius)   [pix]
#  5) 0.4000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.7040      1          #  Axis ratio (b/a)
# 10) -31.2216    2          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....

# %%
# make galfit plots
gal.plot_all(obj_id, field, num='01', s=50)
# Out:
# Making plots...: 100%|████████████████████████████| 6/6 [00:04<00:00,  1.31it/s]

# %%
# make aperture plots
gal.plot_all_apertures(obj_id, field, num='01', components=['bulge', 'disk'], frac_hl=2)
# Out:
# Making plots...:   0%|                                    | 0/6 [00:00<?, ?it/s]WARNING: No meaningful fit was possible. [photutils.isophote.ellipse]
# Making plots...:  17%|████▋                       | 1/6 [00:00<00:00,  7.05it/s]WARNING: No meaningful fit was possible. [photutils.isophote.ellipse]
# fatal error 1!!!
# fatal error 1!!!
# Making plots...:  67%|██████████████████▋         | 4/6 [00:18<00:10,  5.29s/it]WARNING: No meaningful fit was possible. [photutils.isophote.ellipse]
# fatal error 1!!!
# Making plots...: 100%|████████████████████████████| 6/6 [00:27<00:00,  4.51s/it]
