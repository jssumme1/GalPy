# %%
import os
from glob import glob
from tqdm import tqdm
import importlib

import matplotlib
matplotlib.use('Agg')
matplotlib.rc('font', family='serif', serif='cm')
matplotlib.rc('text', usetex=True)
matplotlib.rc('ps', usedistiller='xpdf')
# %matplotlib inline

import Galfit
importlib.reload(Galfit)
# Out:
# <module 'Galfit' from '/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py'>

# %%
# PARAMETERS THAT CHANGE FOR DIFFERENT DATASETS AND OBJECTS *******
field = 'g191'
date = '20230718'
img_size = 100 # (max = 333/2)
psf_size = 100 # usually 100 for both sizes
star = False

# %%
#directories
image_dir = f'/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/{field}/mosaics'
object_dir = f'/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/{field}/objects'
psf_dir =  f'/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/{field}/psfs'

# catalog
cat_dir = f'/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/{field}/cats'
master_cat = os.path.join(cat_dir, f'{field.upper()}_total_cat_extinction.txt')
cats = glob(os.path.join(cat_dir, f'{field.upper()}_F*_cat.txt'))
cats.sort()

# i2d images
images = glob(os.path.join(image_dir, f'mosaic_{field}_nircam_*_30mas_{date}_i2d.fits'))
images.sort()

# %%
# initialize galfit and create psf cutouts
gal = Galfit.Galfit(field, images, cats, master_cat, img_size=img_size, psf_size=psf_size, star=star,
             image_dir=image_dir, object_dir=object_dir, psf_dir=psf_dir, cat_dir=cat_dir)
# Out:
# Creating PSF cutouts...: 100%|████████████████████| 8/8 [00:00<00:00, 65.57it/s]

# %%
clio_cool_objects = [4582, 3906, 1620, 4717, 4741, 4764, 4509, 1315, 1591, 627, 1179, 383]
g191_cool_objects = [677, 874, 1509, 422, 2013, 1780, 1763, 2004, 2764, 3003, 4560, 5033, 4962, 4795, 5300, 4840, 4827, 4763, 5359, 6175, 8994, 8637]
# 4582 is best

# %%
obj_id = 1509 #4582 is very nice

gal.make_object(obj_id, overwrite=True)
# Out:
# Creating object cutouts...: 100%|█████████████████| 8/8 [00:00<00:00, 11.79it/s]

# %%
# run
for im in tqdm(images, desc='Running GALFIT...'):
    filt = im.split('_')[-4]
    gal.add_component(obj_id, filt, 'sersic', bulge=True)
    gal.add_component(obj_id, filt, 'sersic', bulge=False)
    
    gal.add_constraints(obj_id, filt, '1-2  mag  -2 2') # constrain bulge and disk to be within a few magnitues
    gal.add_constraints(obj_id, filt, '1_2  x    ratio') # keeps x position fixed between components
    gal.add_constraints(obj_id, filt, '1_2  y    ratio') # keeps y position fixed between components
    gal.add_constraints(obj_id, filt, '1    n    2 to 10') # fix bulge sersic index between 2 and 10
    gal.add_constraints(obj_id, filt, '2    n    0.1 to 2') # fix disk sersic index between 0.4 to 5
    gal.add_constraints(obj_id, filt, '1-2  n    0.1 10') # force bulge sersic > disk sersic
    #gal.add_constraints(obj_id, filt, '2/1  re   1 8') # fix disk/bulge half light radius to be ratio 1 to 8
    
    gal.run(obj_id, filt, num='01', overwrite=True)
# Out:
# Running GALFIT...:   0%|                                  | 0/8 [00:00<?, ?it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f090w_sci.fits      # Input data image (FITS file)
# B) obj_1509_f090w_imgblock01.fits      # Output data image block
# C) obj_1509_f090w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f090w_webbpsf_cutout.fits          # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f090w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 0                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.0000 100.0000 1 1  #  Position x, y
#  3) 23.8830     1          #  Integrated magnitude
#  4) 0.6183      1          #  R_e (effective radius)   [pix]
#  5) 5.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8870      1          #  Axis ratio (b/a)
# 10) 211.4200    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.0000 100.0000 1 1  #  Position x, y
#  3) 23.8830     1          #  Integrated magnitude
#  4) 1.2367      1          #  R_e (effective radius)   [pix]
#  5) 1.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8870      1          #  Axis ratio (b/a)
# 10) 211.4200    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
# ================================================================================
# Initial parameters:
#  sersic    : (  100.00,   100.00)   23.88      0.62    5.00    0.89    31.42
#  sersic    : ( {100.00}, {100.00})  23.88      1.24    1.00    0.89    31.42
# ================================================================================
#
# Iteration : 1     Chi2nu: 2.203e+00     dChi2/Chi2: -1.16e+22   alamda: 1e-03
#  sersic    : (  100.10,   100.11)   24.31      1.21  *10.00*   0.73   -26.27
#  sersic    : ( {100.10}, {100.11})  24.42      1.19    0.62    0.77    47.53
# COUNTDOWN = 99
#
# Iteration : 2     Chi2nu: 1.684e+00     dChi2/Chi2: -3.08e-01   alamda: 1e-04
#  sersic    : (  100.24,   100.27)   23.20      7.18  *10.00*   0.77   -25.33
#  sersic    : ( {100.24}, {100.27})  25.20      1.05    0.77    0.97    37.50
# COUNTDOWN = 98
#
# Iteration : 3     Chi2nu: 6.768e-01     dChi2/Chi2: -1.49e+00   alamda: 1e-05
#  sersic    : (  100.39,   100.43)   24.96      9.89    9.02    1.00   -25.57
#  sersic    : ( {100.39}, {100.43})  26.96      1.50    2.00    0.95   -56.76
# COUNTDOWN = 97
#
# Iteration : 4     Chi2nu: 6.768e-01     dChi2/Chi2: -1.49e-08   alamda: 1e-04
#  sersic    : (  100.39,   100.43)   24.96      9.89    9.02    1.00   -25.57
#  sersic    : ( {100.39}, {100.43})  26.96      1.50    2.00    0.95   -56.76
# COUNTDOWN = 10
#
# Iteration : 5     Chi2nu: 6.768e-01     dChi2/Chi2: -1.49e-08   alamda: 1e-03
#  sersic    : (  100.39,   100.43)   24.96      9.89    9.02    1.00   -25.57
#  sersic    : ( {100.39}, {100.43})  26.96      1.50    2.00    0.95   -56.76
# COUNTDOWN = 9
#
# Iteration : 6     Chi2nu: 6.768e-01     dChi2/Chi2: -1.49e-08   alamda: 1e-02
#  sersic    : (  100.39,   100.43)   24.96      9.89    9.02    1.00   -25.57
#  sersic    : ( {100.39}, {100.43})  26.96      1.50    2.00    0.95   -56.76
# COUNTDOWN = 8
#
# Iteration : 7     Chi2nu: 6.768e-01     dChi2/Chi2: -1.49e-08   alamda: 1e-01
#  sersic    : (  100.39,   100.43)   24.96      9.89    9.02    1.00   -25.57
#  sersic    : ( {100.39}, {100.43})  26.96      1.50    2.00    0.95   -56.76
# COUNTDOWN = 7
#
# Iteration : 8     Chi2nu: 6.768e-01     dChi2/Chi2: -1.49e-08   alamda: 1e+00
#  sersic    : (  100.39,   100.43)   24.96      9.89    9.02    1.00   -25.57
#  sersic    : ( {100.39}, {100.43})  26.96      1.50    2.00    0.95   -56.76
# COUNTDOWN = 6
#
# Iteration : 9     Chi2nu: 6.117e-01     dChi2/Chi2: -1.06e-01   alamda: 1e-01
#  sersic    : (  100.67,   100.79)   24.26      3.18    3.58    0.53    67.92
#  sersic    : ( {100.67}, {100.79})  25.59      2.30    2.00    0.59   -67.03
# COUNTDOWN = 91
#
# Iteration : 10    Chi2nu: 5.185e-01     dChi2/Chi2: -1.80e-01   alamda: 1e-02
#  sersic    : (  100.65,   100.76)   24.24      4.23    3.38    0.77    70.41
#  sersic    : ( {100.65}, {100.76})  25.63      3.73    2.00    0.90   -60.11
# COUNTDOWN = 90
#
# Iteration : 11    Chi2nu: 5.185e-01     dChi2/Chi2: -2.06e-08   alamda: 1e-01
#  sersic    : (  100.65,   100.76)   24.24      4.23    3.38    0.77    70.41
#  sersic    : ( {100.65}, {100.76})  25.63      3.73    2.00    0.90   -60.11
# COUNTDOWN = 10
#
# Iteration : 12    Chi2nu: 5.124e-01     dChi2/Chi2: -1.20e-02   alamda: 1e-02
#  sersic    : (  100.63,   100.75)   24.14      4.79    2.98    0.89    77.88
#  sersic    : ( {100.63}, {100.75})  25.33      5.56    2.00    0.79   -36.08
# COUNTDOWN = 88
#
# Iteration : 13    Chi2nu: 5.124e-01     dChi2/Chi2: 4.26e-08    alamda: 1e-01
#  sersic    : (  100.63,   100.75)   24.14      4.79    2.98    0.89    77.88
#  sersic    : ( {100.63}, {100.75})  25.33      5.56    2.00    0.79   -36.08
# COUNTDOWN = 10
#
# Iteration : 14    Chi2nu: 5.102e-01     dChi2/Chi2: -4.24e-03   alamda: 1e-02
#  sersic    : (  100.63,   100.76)   24.10      5.07    3.28    0.93    77.64
#  sersic    : ( {100.63}, {100.76})  25.19      7.38    2.00    0.96   -25.11
# COUNTDOWN = 86
#
# Iteration : 15    Chi2nu: 5.098e-01     dChi2/Chi2: -8.18e-04   alamda: 1e-03
#  sersic    : (  100.63,   100.76)   24.04      5.49    3.49    0.87    39.34
#  sersic    : ( {100.63}, {100.76})  24.96     12.05    2.00    0.78   -62.12
# COUNTDOWN = 85
#
# Iteration : 16    Chi2nu: 5.092e-01     dChi2/Chi2: -1.23e-03   alamda: 1e-04
#  sersic    : (  100.63,   100.76)   23.99      4.61    3.08    0.91    55.86
#  sersic    : ( {100.63}, {100.76})  24.83     22.52    2.00    0.76   -46.79
# COUNTDOWN = 84
#
# Iteration : 17    Chi2nu: 5.092e-01     dChi2/Chi2: -2.70e-08   alamda: 1e-03
#  sersic    : (  100.63,   100.76)   23.99      4.61    3.08    0.91    55.86
#  sersic    : ( {100.63}, {100.76})  24.83     22.52    2.00    0.76   -46.79
# COUNTDOWN = 10
#
# Iteration : 18    Chi2nu: 5.092e-01     dChi2/Chi2: -2.70e-08   alamda: 1e-02
#  sersic    : (  100.63,   100.76)   23.99      4.61    3.08    0.91    55.86
#  sersic    : ( {100.63}, {100.76})  24.83     22.52    2.00    0.76   -46.79
# COUNTDOWN = 9
#
# Iteration : 19    Chi2nu: 5.092e-01     dChi2/Chi2: -2.70e-08   alamda: 1e-01
#  sersic    : (  100.63,   100.76)   23.99      4.61    3.08    0.91    55.86
#  sersic    : ( {100.63}, {100.76})  24.83     22.52    2.00    0.76   -46.79
# COUNTDOWN = 8
#
# Iteration : 20    Chi2nu: 5.081e-01     dChi2/Chi2: -2.04e-03   alamda: 1e-02
#  sersic    : (  100.63,   100.76)   24.01      4.68    3.21    0.90    55.82
#  sersic    : ( {100.63}, {100.76})  24.69     30.86    2.00    0.75   -46.42
# COUNTDOWN = 80
#
# Iteration : 21    Chi2nu: 5.081e-01     dChi2/Chi2: 3.84e-08    alamda: 1e-01
#  sersic    : (  100.63,   100.76)   24.01      4.68    3.21    0.90    55.82
#  sersic    : ( {100.63}, {100.76})  24.69     30.86    2.00    0.75   -46.42
# COUNTDOWN = 10
#
# Iteration : 22    Chi2nu: 5.079e-01     dChi2/Chi2: -3.98e-04   alamda: 1e-02
#  sersic    : (  100.63,   100.76)   24.01      4.71    3.23    0.89    54.05
#  sersic    : ( {100.63}, {100.76})  24.43     42.65    2.00    0.69   -50.99
# COUNTDOWN = 78
#
# Iteration : 23    Chi2nu: 5.079e-01     dChi2/Chi2: -1.82e-08   alamda: 1e-01
#  sersic    : (  100.63,   100.76)   24.01      4.71    3.23    0.89    54.05
#  sersic    : ( {100.63}, {100.76})  24.43     42.65    2.00    0.69   -50.99
# COUNTDOWN = 10
#
# Iteration : 24    Chi2nu: 5.076e-01     dChi2/Chi2: -5.27e-04   alamda: 1e-02
#  sersic    : (  100.63,   100.75)   24.00      4.67    3.18    0.89    52.82
#  sersic    : ( {100.63}, {100.75})  24.18     58.99    2.00    0.65   -55.41
# COUNTDOWN = 76
#
# Iteration : 25    Chi2nu: 5.076e-01     dChi2/Chi2: 4.17e-08    alamda: 1e-01
#  sersic    : (  100.63,   100.75)   24.00      4.67    3.18    0.89    52.82
#  sersic    : ( {100.63}, {100.75})  24.18     58.99    2.00    0.65   -55.41
# COUNTDOWN = 10
#
# Iteration : 26    Chi2nu: 5.073e-01     dChi2/Chi2: -6.95e-04   alamda: 1e-02
#  sersic    : (  100.63,   100.75)   23.99      4.61    3.10    0.90    52.57
#  sersic    : ( {100.63}, {100.75})  23.95     80.19    2.00    0.61   -58.84
# COUNTDOWN = 74
#
# Iteration : 27    Chi2nu: 5.073e-01     dChi2/Chi2: -1.66e-08   alamda: 1e-01
#  sersic    : (  100.63,   100.75)   23.99      4.61    3.10    0.90    52.57
#  sersic    : ( {100.63}, {100.75})  23.95     80.19    2.00    0.61   -58.84
# COUNTDOWN = 10
#
# Iteration : 28    Chi2nu: 5.070e-01     dChi2/Chi2: -5.07e-04   alamda: 1e-02
#  sersic    : (  100.63,   100.75)   23.97      4.58    3.04    0.90    53.04
#  sersic    : ( {100.63}, {100.75})  23.74    104.38    2.00    0.58   -61.50
# COUNTDOWN = 72
#
# Iteration : 29    Chi2nu: 5.070e-01     dChi2/Chi2: 1.39e-08    alamda: 1e-01
#  sersic    : (  100.63,   100.75)   23.97      4.58    3.04    0.90    53.04
#  sersic    : ( {100.63}, {100.75})  23.74    104.38    2.00    0.58   -61.50
# COUNTDOWN = 10
#
# Iteration : 30    Chi2nu: 5.069e-01     dChi2/Chi2: -3.10e-04   alamda: 1e-02
#  sersic    : (  100.63,   100.75)   23.96      4.60    3.01    0.91    53.74
#  sersic    : ( {100.63}, {100.75})  23.55    129.74    2.00    0.55   -63.49
# COUNTDOWN = 70
#
# Iteration : 31    Chi2nu: 5.068e-01     dChi2/Chi2: -7.50e-05   alamda: 1e-03
#  sersic    : (  100.63,   100.76)   23.88      5.09    3.23    0.91    53.17
#  sersic    : ( {100.63}, {100.76})  22.51    310.19    2.00    0.42   -65.56
# COUNTDOWN = 10
#
# Iteration : 32    Chi2nu: 5.068e-01     dChi2/Chi2: 2.38e-08    alamda: 1e-02
#  sersic    : (  100.63,   100.76)   23.88      5.09    3.23    0.91    53.17
#  sersic    : ( {100.63}, {100.76})  22.51    310.19    2.00    0.42   -65.56
# COUNTDOWN = 9
#
# Iteration : 33    Chi2nu: 5.065e-01     dChi2/Chi2: -7.40e-04   alamda: 1e-03
#  sersic    : (  100.63,   100.76)   23.83      5.36    3.29    0.93    56.37
#  sersic    : ( {100.63}, {100.76})  22.10    506.97    2.00    0.38   -70.17
# COUNTDOWN = 67
#
# Iteration : 34    Chi2nu: 5.065e-01     dChi2/Chi2: -3.15e-08   alamda: 1e-02
#  sersic    : (  100.63,   100.76)   23.83      5.36    3.29    0.93    56.37
#  sersic    : ( {100.63}, {100.76})  22.10    506.97    2.00    0.38   -70.17
# COUNTDOWN = 10
#
# Iteration : 35    Chi2nu: 5.065e-01     dChi2/Chi2: -3.15e-08   alamda: 1e-01
#  sersic    : (  100.63,   100.76)   23.83      5.36    3.29    0.93    56.37
#  sersic    : ( {100.63}, {100.76})  22.10    506.97    2.00    0.38   -70.17
# COUNTDOWN = 9
#
# Iteration : 36    Chi2nu: 5.063e-01     dChi2/Chi2: -4.08e-04   alamda: 1e-02
#  sersic    : (  100.63,   100.76)   23.82      5.38    3.29    0.93    57.41
#  sersic    : ( {100.63}, {100.76})  22.06    544.93    1.70    0.37   -73.21
# COUNTDOWN = 64
#
# Iteration : 37    Chi2nu: 5.063e-01     dChi2/Chi2: -3.84e-08   alamda: 1e-01
#  sersic    : (  100.63,   100.76)   23.82      5.38    3.29    0.93    57.41
#  sersic    : ( {100.63}, {100.76})  22.06    544.93    1.70    0.37   -73.21
# COUNTDOWN = 10
#
# Iteration : 38    Chi2nu: 5.062e-01     dChi2/Chi2: -8.31e-05   alamda: 1e-02
#  sersic    : (  100.63,   100.76)   23.82      5.41    3.29    0.93    57.94
#  sersic    : ( {100.63}, {100.76})  21.93    561.94    1.46    0.36   -75.53
# COUNTDOWN = 9
#
# Iteration : 39    Chi2nu: 5.062e-01     dChi2/Chi2: 2.92e-09    alamda: 1e-01
#  sersic    : (  100.63,   100.76)   23.82      5.41    3.29    0.93    57.94
#  sersic    : ( {100.63}, {100.76})  21.93    561.94    1.46    0.36   -75.53
# COUNTDOWN = 8
#
# Iteration : 40    Chi2nu: 5.062e-01     dChi2/Chi2: -5.76e-05   alamda: 1e-02
#  sersic    : (  100.63,   100.76)   23.81      5.45    3.30    0.93    58.45
#  sersic    : ( {100.63}, {100.76})  21.82    575.36    1.30    0.35   -77.41
# COUNTDOWN = 7
#
# Iteration : 41    Chi2nu: 5.062e-01     dChi2/Chi2: 4.63e-08    alamda: 1e-01
#  sersic    : (  100.63,   100.76)   23.81      5.45    3.30    0.93    58.45
#  sersic    : ( {100.63}, {100.76})  21.82    575.36    1.30    0.35   -77.41
# COUNTDOWN = 6
#
# Iteration : 42    Chi2nu: 5.062e-01     dChi2/Chi2: 4.63e-08    alamda: 1e+00
#  sersic    : (  100.63,   100.76)   23.81      5.45    3.30    0.93    58.45
#  sersic    : ( {100.63}, {100.76})  21.82    575.36    1.30    0.35   -77.41
# COUNTDOWN = 5
#
# Iteration : 43    Chi2nu: 5.062e-01     dChi2/Chi2: 4.63e-08    alamda: 1e+01
#  sersic    : (  100.63,   100.76)   23.81      5.45    3.30    0.93    58.45
#  sersic    : ( {100.63}, {100.76})  21.82    575.36    1.30    0.35   -77.41
# COUNTDOWN = 4
#
# Iteration : 44    Chi2nu: 5.062e-01     dChi2/Chi2: -8.62e-07   alamda: 1e+00
#  sersic    : (  100.63,   100.76)   23.81      5.45    3.30    0.93    58.45
#  sersic    : ( {100.63}, {100.76})  21.82    575.33    1.30    0.35   -77.54
# COUNTDOWN = 3
#
# Iteration : 45    Chi2nu: 5.062e-01     dChi2/Chi2: 2.42e-08    alamda: 1e+01
#  sersic    : (  100.63,   100.76)   23.81      5.45    3.30    0.93    58.45
#  sersic    : ( {100.63}, {100.76})  21.82    575.33    1.30    0.35   -77.54
# COUNTDOWN = 2
#
# Iteration : 46    Chi2nu: 5.062e-01     dChi2/Chi2: -8.47e-07   alamda: 1e+00
#  sersic    : (  100.63,   100.76)   23.81      5.45    3.30    0.93    58.45
#  sersic    : ( {100.63}, {100.76})  21.82    575.30    1.30    0.35   -77.65
# COUNTDOWN = 1
#
# Iteration : 47    Chi2nu: 5.062e-01     dChi2/Chi2: 3.90e-08    alamda: 1e+01
#  sersic    : (  100.63,   100.76)   23.81      5.45    3.30    0.93    58.45
#  sersic    : ( {100.63}, {100.76})  21.82    575.30    1.30    0.35   -77.65
# COUNTDOWN = 0
# Running GALFIT...:  12%|███▎                      | 1/8 [00:27<03:13, 27.59s/it]
# Fit summary is now being saved into `fit.log'.
#
#
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f115w_sci.fits      # Input data image (FITS file)
# B) obj_1509_f115w_imgblock01.fits      # Output data image block
# C) obj_1509_f115w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f115w_webbpsf_cutout.fits          # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f115w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 0                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.0000 100.0000 1 1  #  Position x, y
#  3) 22.3356     1          #  Integrated magnitude
#  4) 0.6600      1          #  R_e (effective radius)   [pix]
#  5) 5.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8867      1          #  Axis ratio (b/a)
# 10) 212.2900    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.0000 100.0000 1 1  #  Position x, y
#  3) 22.3356     1          #  Integrated magnitude
#  4) 1.3200      1          #  R_e (effective radius)   [pix]
#  5) 1.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8867      1          #  Axis ratio (b/a)
# 10) 212.2900    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
# ================================================================================
# Initial parameters:
#  sersic    : (  100.00,   100.00)   22.34      0.66    5.00    0.89    32.29
#  sersic    : ( {100.00}, {100.00})  22.34      1.32    1.00    0.89    32.29
# ================================================================================
#
# Iteration : 1     Chi2nu: 9.371e+00     dChi2/Chi2: -2.72e+21   alamda: 1e-03
#  sersic    : (  100.06,   100.08)   22.80      1.41  *10.00*   0.84    -2.14
#  sersic    : ( {100.06}, {100.08})  22.87      1.21    0.79    0.82    43.19
# COUNTDOWN = 99
#
# Iteration : 2     Chi2nu: 1.256e+00     dChi2/Chi2: -6.46e+00   alamda: 1e-04
#  sersic    : (  100.14,   100.19)   22.17      6.69    2.00    0.76    55.34
#  sersic    : ( {100.14}, {100.19})  24.17      1.16    0.68    0.91    31.18
# COUNTDOWN = 98
#
# Iteration : 3     Chi2nu: 6.158e-01     dChi2/Chi2: -1.04e+00   alamda: 1e-05
#  sersic    : (  100.33,   100.46)   22.52      7.25    2.00    0.85    51.95
#  sersic    : ( {100.33}, {100.46})  23.90      1.38    0.69    0.94    32.44
# COUNTDOWN = 97
#
# Iteration : 4     Chi2nu: 6.158e-01     dChi2/Chi2: 1.36e-09    alamda: 1e-04
#  sersic    : (  100.33,   100.46)   22.52      7.25    2.00    0.85    51.95
#  sersic    : ( {100.33}, {100.46})  23.90      1.38    0.69    0.94    32.44
# COUNTDOWN = 10
#
# Iteration : 5     Chi2nu: 6.158e-01     dChi2/Chi2: 1.36e-09    alamda: 1e-03
#  sersic    : (  100.33,   100.46)   22.52      7.25    2.00    0.85    51.95
#  sersic    : ( {100.33}, {100.46})  23.90      1.38    0.69    0.94    32.44
# COUNTDOWN = 9
#
# Iteration : 6     Chi2nu: 5.867e-01     dChi2/Chi2: -4.97e-02   alamda: 1e-04
#  sersic    : (  100.45,   100.63)   22.71      8.15    2.00    0.90    44.27
#  sersic    : ( {100.45}, {100.63})  23.59      1.42    0.94    0.90   -88.71
# COUNTDOWN = 94
#
# Iteration : 7     Chi2nu: 5.794e-01     dChi2/Chi2: -1.25e-02   alamda: 1e-05
#  sersic    : (  100.50,   100.68)   22.79      8.28    2.00    0.90    36.43
#  sersic    : ( {100.50}, {100.68})  23.53      1.45    1.03    0.93    40.85
# COUNTDOWN = 93
#
# Iteration : 8     Chi2nu: 5.661e-01     dChi2/Chi2: -2.35e-02   alamda: 1e-06
#  sersic    : (  100.52,   100.72)   22.74      7.70    2.00    0.91    39.92
#  sersic    : ( {100.52}, {100.72})  23.65      1.45    0.95    0.84    77.74
# COUNTDOWN = 92
#
# Iteration : 9     Chi2nu: 5.661e-01     dChi2/Chi2: 4.22e-08    alamda: 1e-05
#  sersic    : (  100.52,   100.72)   22.74      7.70    2.00    0.91    39.92
#  sersic    : ( {100.52}, {100.72})  23.65      1.45    0.95    0.84    77.74
# COUNTDOWN = 10
#
# Iteration : 10    Chi2nu: 5.661e-01     dChi2/Chi2: 4.22e-08    alamda: 1e-04
#  sersic    : (  100.52,   100.72)   22.74      7.70    2.00    0.91    39.92
#  sersic    : ( {100.52}, {100.72})  23.65      1.45    0.95    0.84    77.74
# COUNTDOWN = 9
#
# Iteration : 11    Chi2nu: 5.661e-01     dChi2/Chi2: 4.22e-08    alamda: 1e-03
#  sersic    : (  100.52,   100.72)   22.74      7.70    2.00    0.91    39.92
#  sersic    : ( {100.52}, {100.72})  23.65      1.45    0.95    0.84    77.74
# COUNTDOWN = 8
#
# Iteration : 12    Chi2nu: 5.661e-01     dChi2/Chi2: 4.22e-08    alamda: 1e-02
#  sersic    : (  100.52,   100.72)   22.74      7.70    2.00    0.91    39.92
#  sersic    : ( {100.52}, {100.72})  23.65      1.45    0.95    0.84    77.74
# COUNTDOWN = 7
#
# Iteration : 13    Chi2nu: 5.579e-01     dChi2/Chi2: -1.46e-02   alamda: 1e-03
#  sersic    : (  100.54,   100.74)   22.73      8.18    2.00    0.90    41.12
#  sersic    : ( {100.54}, {100.74})  23.63      1.43    0.99    0.87    55.42
# COUNTDOWN = 87
#
# Iteration : 14    Chi2nu: 5.579e-01     dChi2/Chi2: -2.23e-08   alamda: 1e-02
#  sersic    : (  100.54,   100.74)   22.73      8.18    2.00    0.90    41.12
#  sersic    : ( {100.54}, {100.74})  23.63      1.43    0.99    0.87    55.42
# COUNTDOWN = 10
#
# Iteration : 15    Chi2nu: 5.539e-01     dChi2/Chi2: -7.26e-03   alamda: 1e-03
#  sersic    : (  100.54,   100.75)   22.72      7.90    2.00    0.91    40.32
#  sersic    : ( {100.54}, {100.75})  23.65      1.48    0.98    0.82    56.11
# COUNTDOWN = 85
#
# Iteration : 16    Chi2nu: 5.539e-01     dChi2/Chi2: -3.25e-09   alamda: 1e-02
#  sersic    : (  100.54,   100.75)   22.72      7.90    2.00    0.91    40.32
#  sersic    : ( {100.54}, {100.75})  23.65      1.48    0.98    0.82    56.11
# COUNTDOWN = 10
#
# Iteration : 17    Chi2nu: 5.539e-01     dChi2/Chi2: -3.25e-09   alamda: 1e-01
#  sersic    : (  100.54,   100.75)   22.72      7.90    2.00    0.91    40.32
#  sersic    : ( {100.54}, {100.75})  23.65      1.48    0.98    0.82    56.11
# COUNTDOWN = 9
#
# Iteration : 18    Chi2nu: 5.400e-01     dChi2/Chi2: -2.57e-02   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.68      8.06    2.00    0.91    41.30
#  sersic    : ( {100.55}, {100.75})  23.69      1.50    1.02    0.81    56.77
# COUNTDOWN = 82
#
# Iteration : 19    Chi2nu: 5.400e-01     dChi2/Chi2: -1.66e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.68      8.06    2.00    0.91    41.30
#  sersic    : ( {100.55}, {100.75})  23.69      1.50    1.02    0.81    56.77
# COUNTDOWN = 10
#
# Iteration : 20    Chi2nu: 5.348e-01     dChi2/Chi2: -9.82e-03   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.66      8.02    2.00    0.91    40.71
#  sersic    : ( {100.55}, {100.75})  23.72      1.51    1.01    0.81    57.40
# COUNTDOWN = 80
#
# Iteration : 21    Chi2nu: 5.348e-01     dChi2/Chi2: -4.11e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.66      8.02    2.00    0.91    40.71
#  sersic    : ( {100.55}, {100.75})  23.72      1.51    1.01    0.81    57.40
# COUNTDOWN = 10
#
# Iteration : 22    Chi2nu: 5.321e-01     dChi2/Chi2: -5.00e-03   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.64      7.96    2.00    0.91    40.86
#  sersic    : ( {100.55}, {100.75})  23.75      1.50    1.00    0.80    57.54
# COUNTDOWN = 78
#
# Iteration : 23    Chi2nu: 5.321e-01     dChi2/Chi2: -2.15e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.64      7.96    2.00    0.91    40.86
#  sersic    : ( {100.55}, {100.75})  23.75      1.50    1.00    0.80    57.54
# COUNTDOWN = 10
#
# Iteration : 24    Chi2nu: 5.304e-01     dChi2/Chi2: -3.31e-03   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.63      7.90    2.00    0.91    41.16
#  sersic    : ( {100.55}, {100.75})  23.78      1.49    0.98    0.80    57.56
# COUNTDOWN = 76
#
# Iteration : 25    Chi2nu: 5.304e-01     dChi2/Chi2: -3.25e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.63      7.90    2.00    0.91    41.16
#  sersic    : ( {100.55}, {100.75})  23.78      1.49    0.98    0.80    57.56
# COUNTDOWN = 10
#
# Iteration : 26    Chi2nu: 5.290e-01     dChi2/Chi2: -2.55e-03   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.62      7.85    2.00    0.91    41.50
#  sersic    : ( {100.55}, {100.75})  23.80      1.48    0.96    0.80    57.55
# COUNTDOWN = 74
#
# Iteration : 27    Chi2nu: 5.290e-01     dChi2/Chi2: 2.35e-08    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.62      7.85    2.00    0.91    41.50
#  sersic    : ( {100.55}, {100.75})  23.80      1.48    0.96    0.80    57.55
# COUNTDOWN = 10
#
# Iteration : 28    Chi2nu: 5.279e-01     dChi2/Chi2: -2.11e-03   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.61      7.80    2.00    0.91    41.82
#  sersic    : ( {100.55}, {100.75})  23.82      1.47    0.94    0.80    57.52
# COUNTDOWN = 72
#
# Iteration : 29    Chi2nu: 5.279e-01     dChi2/Chi2: -1.92e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.61      7.80    2.00    0.91    41.82
#  sersic    : ( {100.55}, {100.75})  23.82      1.47    0.94    0.80    57.52
# COUNTDOWN = 10
#
# Iteration : 30    Chi2nu: 5.270e-01     dChi2/Chi2: -1.80e-03   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.61      7.75    2.00    0.91    42.11
#  sersic    : ( {100.55}, {100.75})  23.84      1.46    0.93    0.80    57.48
# COUNTDOWN = 70
#
# Iteration : 31    Chi2nu: 5.270e-01     dChi2/Chi2: 4.07e-08    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.61      7.75    2.00    0.91    42.11
#  sersic    : ( {100.55}, {100.75})  23.84      1.46    0.93    0.80    57.48
# COUNTDOWN = 10
#
# Iteration : 32    Chi2nu: 5.261e-01     dChi2/Chi2: -1.55e-03   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.60      7.71    2.00    0.90    42.37
#  sersic    : ( {100.55}, {100.75})  23.86      1.45    0.92    0.80    57.45
# COUNTDOWN = 68
#
# Iteration : 33    Chi2nu: 5.261e-01     dChi2/Chi2: 1.39e-08    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.60      7.71    2.00    0.90    42.37
#  sersic    : ( {100.55}, {100.75})  23.86      1.45    0.92    0.80    57.45
# COUNTDOWN = 10
#
# Iteration : 34    Chi2nu: 5.254e-01     dChi2/Chi2: -1.33e-03   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.60      7.68    2.00    0.90    42.59
#  sersic    : ( {100.55}, {100.75})  23.88      1.44    0.90    0.80    57.42
# COUNTDOWN = 66
#
# Iteration : 35    Chi2nu: 5.254e-01     dChi2/Chi2: 1.28e-08    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.60      7.68    2.00    0.90    42.59
#  sersic    : ( {100.55}, {100.75})  23.88      1.44    0.90    0.80    57.42
# COUNTDOWN = 10
#
# Iteration : 36    Chi2nu: 5.248e-01     dChi2/Chi2: -1.15e-03   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.59      7.65    2.00    0.90    42.78
#  sersic    : ( {100.55}, {100.75})  23.89      1.44    0.89    0.80    57.39
# COUNTDOWN = 64
#
# Iteration : 37    Chi2nu: 5.248e-01     dChi2/Chi2: 7.45e-09    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.59      7.65    2.00    0.90    42.78
#  sersic    : ( {100.55}, {100.75})  23.89      1.44    0.89    0.80    57.39
# COUNTDOWN = 10
#
# Iteration : 38    Chi2nu: 5.243e-01     dChi2/Chi2: -9.86e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.59      7.62    2.00    0.90    42.94
#  sersic    : ( {100.55}, {100.75})  23.90      1.43    0.88    0.80    57.37
# COUNTDOWN = 62
#
# Iteration : 39    Chi2nu: 5.243e-01     dChi2/Chi2: -2.00e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.59      7.62    2.00    0.90    42.94
#  sersic    : ( {100.55}, {100.75})  23.90      1.43    0.88    0.80    57.37
# COUNTDOWN = 10
#
# Iteration : 40    Chi2nu: 5.239e-01     dChi2/Chi2: -8.45e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.58      7.60    2.00    0.90    43.08
#  sersic    : ( {100.55}, {100.75})  23.91      1.43    0.88    0.80    57.35
# COUNTDOWN = 60
#
# Iteration : 41    Chi2nu: 5.239e-01     dChi2/Chi2: 3.89e-08    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.58      7.60    2.00    0.90    43.08
#  sersic    : ( {100.55}, {100.75})  23.91      1.43    0.88    0.80    57.35
# COUNTDOWN = 10
#
# Iteration : 42    Chi2nu: 5.235e-01     dChi2/Chi2: -7.23e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.58      7.58    2.00    0.90    43.20
#  sersic    : ( {100.55}, {100.75})  23.92      1.42    0.87    0.80    57.33
# COUNTDOWN = 58
#
# Iteration : 43    Chi2nu: 5.235e-01     dChi2/Chi2: 3.54e-08    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.58      7.58    2.00    0.90    43.20
#  sersic    : ( {100.55}, {100.75})  23.92      1.42    0.87    0.80    57.33
# COUNTDOWN = 10
#
# Iteration : 44    Chi2nu: 5.232e-01     dChi2/Chi2: -6.18e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.58      7.56    2.00    0.90    43.30
#  sersic    : ( {100.55}, {100.75})  23.93      1.42    0.86    0.80    57.31
# COUNTDOWN = 56
#
# Iteration : 45    Chi2nu: 5.232e-01     dChi2/Chi2: 2.49e-08    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.58      7.56    2.00    0.90    43.30
#  sersic    : ( {100.55}, {100.75})  23.93      1.42    0.86    0.80    57.31
# COUNTDOWN = 10
#
# Iteration : 46    Chi2nu: 5.229e-01     dChi2/Chi2: -5.29e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.57      7.54    2.00    0.90    43.39
#  sersic    : ( {100.55}, {100.75})  23.94      1.41    0.86    0.80    57.29
# COUNTDOWN = 54
#
# Iteration : 47    Chi2nu: 5.229e-01     dChi2/Chi2: 2.29e-08    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.57      7.54    2.00    0.90    43.39
#  sersic    : ( {100.55}, {100.75})  23.94      1.41    0.86    0.80    57.29
# COUNTDOWN = 10
#
# Iteration : 48    Chi2nu: 5.227e-01     dChi2/Chi2: -4.52e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.57      7.53    2.00    0.90    43.47
#  sersic    : ( {100.55}, {100.75})  23.95      1.41    0.85    0.80    57.28
# COUNTDOWN = 52
#
# Iteration : 49    Chi2nu: 5.227e-01     dChi2/Chi2: -2.02e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.57      7.53    2.00    0.90    43.47
#  sersic    : ( {100.55}, {100.75})  23.95      1.41    0.85    0.80    57.28
# COUNTDOWN = 10
#
# Iteration : 50    Chi2nu: 5.225e-01     dChi2/Chi2: -3.87e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.57      7.52    2.00    0.90    43.54
#  sersic    : ( {100.55}, {100.75})  23.95      1.41    0.85    0.80    57.27
# COUNTDOWN = 50
#
# Iteration : 51    Chi2nu: 5.225e-01     dChi2/Chi2: -3.28e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.57      7.52    2.00    0.90    43.54
#  sersic    : ( {100.55}, {100.75})  23.95      1.41    0.85    0.80    57.27
# COUNTDOWN = 10
#
# Iteration : 52    Chi2nu: 5.223e-01     dChi2/Chi2: -3.31e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.57      7.51    2.00    0.90    43.59
#  sersic    : ( {100.55}, {100.75})  23.96      1.41    0.85    0.80    57.26
# COUNTDOWN = 48
#
# Iteration : 53    Chi2nu: 5.223e-01     dChi2/Chi2: 4.10e-08    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.57      7.51    2.00    0.90    43.59
#  sersic    : ( {100.55}, {100.75})  23.96      1.41    0.85    0.80    57.26
# COUNTDOWN = 10
#
# Iteration : 54    Chi2nu: 5.221e-01     dChi2/Chi2: -2.83e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.57      7.50    2.00    0.90    43.64
#  sersic    : ( {100.55}, {100.75})  23.96      1.41    0.84    0.80    57.25
# COUNTDOWN = 46
#
# Iteration : 55    Chi2nu: 5.221e-01     dChi2/Chi2: -2.29e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.57      7.50    2.00    0.90    43.64
#  sersic    : ( {100.55}, {100.75})  23.96      1.41    0.84    0.80    57.25
# COUNTDOWN = 10
#
# Iteration : 56    Chi2nu: 5.220e-01     dChi2/Chi2: -2.43e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.57      7.49    2.00    0.90    43.68
#  sersic    : ( {100.55}, {100.75})  23.97      1.41    0.84    0.80    57.24
# COUNTDOWN = 44
#
# Iteration : 57    Chi2nu: 5.220e-01     dChi2/Chi2: -1.95e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.57      7.49    2.00    0.90    43.68
#  sersic    : ( {100.55}, {100.75})  23.97      1.41    0.84    0.80    57.24
# COUNTDOWN = 10
#
# Iteration : 58    Chi2nu: 5.219e-01     dChi2/Chi2: -2.08e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.56      7.48    2.00    0.90    43.72
#  sersic    : ( {100.55}, {100.75})  23.97      1.40    0.84    0.80    57.24
# COUNTDOWN = 42
#
# Iteration : 59    Chi2nu: 5.219e-01     dChi2/Chi2: 1.14e-09    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.56      7.48    2.00    0.90    43.72
#  sersic    : ( {100.55}, {100.75})  23.97      1.40    0.84    0.80    57.24
# COUNTDOWN = 10
#
# Iteration : 60    Chi2nu: 5.218e-01     dChi2/Chi2: -1.78e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.56      7.48    2.00    0.90    43.75
#  sersic    : ( {100.55}, {100.75})  23.97      1.40    0.84    0.80    57.23
# COUNTDOWN = 40
#
# Iteration : 61    Chi2nu: 5.218e-01     dChi2/Chi2: 3.47e-08    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.56      7.48    2.00    0.90    43.75
#  sersic    : ( {100.55}, {100.75})  23.97      1.40    0.84    0.80    57.23
# COUNTDOWN = 10
#
# Iteration : 62    Chi2nu: 5.217e-01     dChi2/Chi2: -1.53e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.56      7.47    2.00    0.90    43.78
#  sersic    : ( {100.55}, {100.75})  23.97      1.40    0.84    0.80    57.23
# COUNTDOWN = 38
#
# Iteration : 63    Chi2nu: 5.217e-01     dChi2/Chi2: -4.49e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.56      7.47    2.00    0.90    43.78
#  sersic    : ( {100.55}, {100.75})  23.97      1.40    0.84    0.80    57.23
# COUNTDOWN = 10
#
# Iteration : 64    Chi2nu: 5.217e-01     dChi2/Chi2: -1.31e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.56      7.47    2.00    0.90    43.80
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.84    0.80    57.22
# COUNTDOWN = 36
#
# Iteration : 65    Chi2nu: 5.217e-01     dChi2/Chi2: 9.41e-09    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.56      7.47    2.00    0.90    43.80
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.84    0.80    57.22
# COUNTDOWN = 10
#
# Iteration : 66    Chi2nu: 5.216e-01     dChi2/Chi2: -1.13e-04   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.56      7.47    2.00    0.90    43.82
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.22
# COUNTDOWN = 34
#
# Iteration : 67    Chi2nu: 5.216e-01     dChi2/Chi2: -2.69e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.56      7.47    2.00    0.90    43.82
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.22
# COUNTDOWN = 10
#
# Iteration : 68    Chi2nu: 5.216e-01     dChi2/Chi2: -9.70e-05   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.56      7.46    2.00    0.90    43.84
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.21
# COUNTDOWN = 9
#
# Iteration : 69    Chi2nu: 5.216e-01     dChi2/Chi2: 5.20e-09    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.56      7.46    2.00    0.90    43.84
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.21
# COUNTDOWN = 8
#
# Iteration : 70    Chi2nu: 5.215e-01     dChi2/Chi2: -8.31e-05   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.56      7.46    2.00    0.90    43.85
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.21
# COUNTDOWN = 7
#
# Iteration : 71    Chi2nu: 5.215e-01     dChi2/Chi2: -3.84e-08   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.56      7.46    2.00    0.90    43.85
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.21
# COUNTDOWN = 6
#
# Iteration : 72    Chi2nu: 5.215e-01     dChi2/Chi2: -7.17e-05   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.56      7.46    2.00    0.90    43.87
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.21
# COUNTDOWN = 5
#
# Iteration : 73    Chi2nu: 5.215e-01     dChi2/Chi2: -7.71e-09   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.56      7.46    2.00    0.90    43.87
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.21
# COUNTDOWN = 4
#
# Iteration : 74    Chi2nu: 5.214e-01     dChi2/Chi2: -6.16e-05   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.56      7.46    2.00    0.90    43.88
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.21
# COUNTDOWN = 3
#
# Iteration : 75    Chi2nu: 5.214e-01     dChi2/Chi2: 2.83e-09    alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.56      7.46    2.00    0.90    43.88
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.21
# COUNTDOWN = 2
#
# Iteration : 76    Chi2nu: 5.214e-01     dChi2/Chi2: -5.30e-05   alamda: 1e-02
#  sersic    : (  100.55,   100.75)   22.56      7.45    2.00    0.90    43.89
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.20
# COUNTDOWN = 1
#
# Iteration : 77    Chi2nu: 5.214e-01     dChi2/Chi2: -8.65e-09   alamda: 1e-01
#  sersic    : (  100.55,   100.75)   22.56      7.45    2.00    0.90    43.89
#  sersic    : ( {100.55}, {100.75})  23.98      1.40    0.83    0.80    57.20
# COUNTDOWN = 0
# Running GALFIT...:  25%|██████▌                   | 2/8 [01:11<03:41, 36.96s/it]
# Fit summary is now being saved into `fit.log'.
#
#
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f150w_sci.fits      # Input data image (FITS file)
# B) obj_1509_f150w_imgblock01.fits      # Output data image block
# C) obj_1509_f150w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f150w_webbpsf_cutout.fits          # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f150w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 0                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.0000 100.0000 1 1  #  Position x, y
#  3) 21.7059     1          #  Integrated magnitude
#  4) 0.6850      1          #  R_e (effective radius)   [pix]
#  5) 5.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8854      1          #  Axis ratio (b/a)
# 10) 212.4000    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.0000 100.0000 1 1  #  Position x, y
#  3) 21.7059     1          #  Integrated magnitude
#  4) 1.3700      1          #  R_e (effective radius)   [pix]
#  5) 1.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8854      1          #  Axis ratio (b/a)
# 10) 212.4000    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
# ================================================================================
# Initial parameters:
#  sersic    : (  100.00,   100.00)   21.71      0.69    5.00    0.89    32.40
#  sersic    : ( {100.00}, {100.00})  21.71      1.37    1.00    0.89    32.40
# ================================================================================
#
# Iteration : 1     Chi2nu: 1.597e+01     dChi2/Chi2: -1.60e+21   alamda: 1e-03
#  sersic    : (  100.05,   100.07)   22.17      1.49  *10.00*   0.86     4.47
#  sersic    : ( {100.05}, {100.07})  22.21      1.25    0.82    0.83    37.91
# COUNTDOWN = 99
#
# Iteration : 2     Chi2nu: 4.035e+00     dChi2/Chi2: -2.96e+00   alamda: 1e-04
#  sersic    : (  100.13,   100.16)   21.51      6.88  *10.00*   0.83    72.11
#  sersic    : ( {100.13}, {100.16})  23.51      1.21    0.67    0.93    21.37
# COUNTDOWN = 98
#
# Iteration : 3     Chi2nu: 4.035e+00     dChi2/Chi2: 4.28e-08    alamda: 1e-03
#  sersic    : (  100.13,   100.16)   21.51      6.88  *10.00*   0.83    72.11
#  sersic    : ( {100.13}, {100.16})  23.51      1.21    0.67    0.93    21.37
# COUNTDOWN = 10
#
# Iteration : 4     Chi2nu: 4.035e+00     dChi2/Chi2: 4.28e-08    alamda: 1e-02
#  sersic    : (  100.13,   100.16)   21.51      6.88  *10.00*   0.83    72.11
#  sersic    : ( {100.13}, {100.16})  23.51      1.21    0.67    0.93    21.37
# COUNTDOWN = 9
#
# Iteration : 5     Chi2nu: 2.378e+00     dChi2/Chi2: -6.97e-01   alamda: 1e-03
#  sersic    : (  100.29,   100.38)   22.30      5.38  *10.00*   0.99    50.11
#  sersic    : ( {100.29}, {100.38})  24.30      1.21    0.62    0.88   -41.01
# COUNTDOWN = 95
#
# Iteration : 6     Chi2nu: 2.378e+00     dChi2/Chi2: -3.93e-08   alamda: 1e-02
#  sersic    : (  100.29,   100.38)   22.30      5.38  *10.00*   0.99    50.11
#  sersic    : ( {100.29}, {100.38})  24.30      1.21    0.62    0.88   -41.01
# COUNTDOWN = 10
#
# Iteration : 7     Chi2nu: 2.378e+00     dChi2/Chi2: -3.93e-08   alamda: 1e-01
#  sersic    : (  100.29,   100.38)   22.30      5.38  *10.00*   0.99    50.11
#  sersic    : ( {100.29}, {100.38})  24.30      1.21    0.62    0.88   -41.01
# COUNTDOWN = 9
#
# Iteration : 8     Chi2nu: 1.866e+00     dChi2/Chi2: -2.74e-01   alamda: 1e-02
#  sersic    : (  100.50,   100.65)   21.81      5.45  *10.00*   0.75     5.63
#  sersic    : ( {100.50}, {100.65})  23.81      1.23    1.67    0.83   -57.33
# COUNTDOWN = 92
#
# Iteration : 9     Chi2nu: 1.866e+00     dChi2/Chi2: -3.31e-08   alamda: 1e-01
#  sersic    : (  100.50,   100.65)   21.81      5.45  *10.00*   0.75     5.63
#  sersic    : ( {100.50}, {100.65})  23.81      1.23    1.67    0.83   -57.33
# COUNTDOWN = 10
#
# Iteration : 10    Chi2nu: 1.445e+00     dChi2/Chi2: -2.92e-01   alamda: 1e-02
#  sersic    : (  100.55,   100.72)   21.98      7.00  *10.00*   0.98    19.98
#  sersic    : ( {100.55}, {100.72})  23.98      1.75    2.00    0.92    73.17
# COUNTDOWN = 90
#
# Iteration : 11    Chi2nu: 1.445e+00     dChi2/Chi2: 2.51e-09    alamda: 1e-01
#  sersic    : (  100.55,   100.72)   21.98      7.00  *10.00*   0.98    19.98
#  sersic    : ( {100.55}, {100.72})  23.98      1.75    2.00    0.92    73.17
# COUNTDOWN = 10
#
# Iteration : 12    Chi2nu: 1.115e+00     dChi2/Chi2: -2.96e-01   alamda: 1e-02
#  sersic    : (  100.59,   100.77)   21.78      6.58  *10.00*   0.87   -29.07
#  sersic    : ( {100.59}, {100.77})  23.43      3.51    2.00    0.72     7.66
# COUNTDOWN = 88
#
# Iteration : 13    Chi2nu: 9.129e-01     dChi2/Chi2: -2.21e-01   alamda: 1e-03
#  sersic    : (  100.60,   100.79)   21.98      5.13  *10.00*   0.97    -9.40
#  sersic    : ( {100.60}, {100.79})  22.88      4.25    2.00    0.94    47.23
# COUNTDOWN = 87
#
# Iteration : 14    Chi2nu: 9.129e-01     dChi2/Chi2: -5.43e-08   alamda: 1e-02
#  sersic    : (  100.60,   100.79)   21.98      5.13  *10.00*   0.97    -9.40
#  sersic    : ( {100.60}, {100.79})  22.88      4.25    2.00    0.94    47.23
# COUNTDOWN = 10
#
# Iteration : 15    Chi2nu: 8.151e-01     dChi2/Chi2: -1.20e-01   alamda: 1e-03
#  sersic    : (  100.60,   100.79)   22.11      4.78  *10.00*   0.98   -52.60
#  sersic    : ( {100.60}, {100.79})  22.76      5.48    2.00    0.83    65.52
# COUNTDOWN = 85
#
# Iteration : 16    Chi2nu: 8.151e-01     dChi2/Chi2: -4.89e-09   alamda: 1e-02
#  sersic    : (  100.60,   100.79)   22.11      4.78  *10.00*   0.98   -52.60
#  sersic    : ( {100.60}, {100.79})  22.76      5.48    2.00    0.83    65.52
# COUNTDOWN = 10
#
# Iteration : 17    Chi2nu: 8.151e-01     dChi2/Chi2: -4.89e-09   alamda: 1e-01
#  sersic    : (  100.60,   100.79)   22.11      4.78  *10.00*   0.98   -52.60
#  sersic    : ( {100.60}, {100.79})  22.76      5.48    2.00    0.83    65.52
# COUNTDOWN = 9
#
# Iteration : 18    Chi2nu: 7.592e-01     dChi2/Chi2: -7.36e-02   alamda: 1e-02
#  sersic    : (  100.60,   100.80)   22.11      5.58    2.33    0.87    81.68
#  sersic    : ( {100.60}, {100.80})  22.65      5.40    2.00    0.89    50.02
# COUNTDOWN = 82
#
# Iteration : 19    Chi2nu: 6.274e-01     dChi2/Chi2: -2.10e-01   alamda: 1e-03
#  sersic    : (  100.59,   100.80)   22.13      4.54    2.75    0.84    56.74
#  sersic    : ( {100.59}, {100.80})  22.68      6.53    2.00    0.97     0.05
# COUNTDOWN = 81
#
# Iteration : 20    Chi2nu: 6.274e-01     dChi2/Chi2: -2.99e-08   alamda: 1e-02
#  sersic    : (  100.59,   100.80)   22.13      4.54    2.75    0.84    56.74
#  sersic    : ( {100.59}, {100.80})  22.68      6.53    2.00    0.97     0.05
# COUNTDOWN = 10
#
# Iteration : 21    Chi2nu: 6.274e-01     dChi2/Chi2: -2.99e-08   alamda: 1e-01
#  sersic    : (  100.59,   100.80)   22.13      4.54    2.75    0.84    56.74
#  sersic    : ( {100.59}, {100.80})  22.68      6.53    2.00    0.97     0.05
# COUNTDOWN = 9
#
# ...
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8902      1          #  Axis ratio (b/a)
# 10) 213.8400    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
# ================================================================================
# Initial parameters:
#  sersic    : (  100.00,   100.00)   20.56      1.19    5.00    0.89    33.84
#  sersic    : ( {100.00}, {100.00})  20.56      2.38    1.00    0.89    33.84
# ================================================================================
#
# Iteration : 1     Chi2nu: 3.597e+01     dChi2/Chi2: -7.04e+20   alamda: 1e-03
#  sersic    : (  100.02,   100.02)   21.03      2.82    9.56    0.98   -18.45
#  sersic    : ( {100.02}, {100.02})  21.03      2.08    1.57    0.83    69.14
# COUNTDOWN = 99
#
# Iteration : 2     Chi2nu: 2.465e+01     dChi2/Chi2: -4.59e-01   alamda: 1e-04
#  sersic    : (  100.06,   100.05)   21.47      9.33  *10.00*   0.79    -7.73
#  sersic    : ( {100.06}, {100.05})  21.29      1.41    2.00    0.69    77.17
# COUNTDOWN = 98
#
# Iteration : 3     Chi2nu: 2.465e+01     dChi2/Chi2: -2.17e-08   alamda: 1e-03
#  sersic    : (  100.06,   100.05)   21.47      9.33  *10.00*   0.79    -7.73
#  sersic    : ( {100.06}, {100.05})  21.29      1.41    2.00    0.69    77.17
# COUNTDOWN = 10
#
# Iteration : 4     Chi2nu: 2.465e+01     dChi2/Chi2: -2.17e-08   alamda: 1e-02
#  sersic    : (  100.06,   100.05)   21.47      9.33  *10.00*   0.79    -7.73
#  sersic    : ( {100.06}, {100.05})  21.29      1.41    2.00    0.69    77.17
# COUNTDOWN = 9
#
# Iteration : 5     Chi2nu: 2.465e+01     dChi2/Chi2: -2.17e-08   alamda: 1e-01
#  sersic    : (  100.06,   100.05)   21.47      9.33  *10.00*   0.79    -7.73
#  sersic    : ( {100.06}, {100.05})  21.29      1.41    2.00    0.69    77.17
# COUNTDOWN = 8
#
# Iteration : 6     Chi2nu: 1.556e+01     dChi2/Chi2: -5.84e-01   alamda: 1e-02
#  sersic    : (  100.09,   100.07)   21.26      4.90  *10.00*   0.77    19.56
#  sersic    : ( {100.09}, {100.07})  21.27      2.08    2.00    0.81    69.53
# COUNTDOWN = 94
#
# Iteration : 7     Chi2nu: 1.291e+01     dChi2/Chi2: -2.05e-01   alamda: 1e-03
#  sersic    : (  100.12,   100.10)   21.41      6.40  *10.00*   0.88    -8.08
#  sersic    : ( {100.12}, {100.10})  21.32      2.71    2.00    0.70    70.04
# COUNTDOWN = 93
#
# Iteration : 8     Chi2nu: 1.291e+01     dChi2/Chi2: -3.05e-08   alamda: 1e-02
#  sersic    : (  100.12,   100.10)   21.41      6.40  *10.00*   0.88    -8.08
#  sersic    : ( {100.12}, {100.10})  21.32      2.71    2.00    0.70    70.04
# COUNTDOWN = 10
#
# Iteration : 9     Chi2nu: 1.154e+01     dChi2/Chi2: -1.18e-01   alamda: 1e-03
#  sersic    : (  100.16,   100.13)   21.55      2.31  *10.00*   0.57    10.81
#  sersic    : ( {100.16}, {100.13})  21.25      3.54    2.00    0.69    65.62
# COUNTDOWN = 91
#
# Iteration : 10    Chi2nu: 6.269e+00     dChi2/Chi2: -8.41e-01   alamda: 1e-04
#  sersic    : (  100.19,   100.16)   21.45      8.59  *10.00*   0.99    -3.98
#  sersic    : ( {100.19}, {100.16})  21.15      4.10    2.00    0.73    67.03
# COUNTDOWN = 90
#
# Iteration : 11    Chi2nu: 5.049e+00     dChi2/Chi2: -2.42e-01   alamda: 1e-05
#  sersic    : (  100.21,   100.18)   22.55      8.50  *10.00*   0.31   -16.73
#  sersic    : ( {100.21}, {100.18})  20.55      4.03    2.00    0.81    60.61
# COUNTDOWN = 89
#
# Iteration : 12    Chi2nu: 5.049e+00     dChi2/Chi2: 8.25e-09    alamda: 1e-04
#  sersic    : (  100.21,   100.18)   22.55      8.50  *10.00*   0.31   -16.73
#  sersic    : ( {100.21}, {100.18})  20.55      4.03    2.00    0.81    60.61
# COUNTDOWN = 10
#
# Iteration : 13    Chi2nu: 5.049e+00     dChi2/Chi2: 8.25e-09    alamda: 1e-03
#  sersic    : (  100.21,   100.18)   22.55      8.50  *10.00*   0.31   -16.73
#  sersic    : ( {100.21}, {100.18})  20.55      4.03    2.00    0.81    60.61
# COUNTDOWN = 9
#
# Iteration : 14    Chi2nu: 5.049e+00     dChi2/Chi2: 8.25e-09    alamda: 1e-02
#  sersic    : (  100.21,   100.18)   22.55      8.50  *10.00*   0.31   -16.73
#  sersic    : ( {100.21}, {100.18})  20.55      4.03    2.00    0.81    60.61
# COUNTDOWN = 8
#
# Iteration : 15    Chi2nu: 5.049e+00     dChi2/Chi2: 8.25e-09    alamda: 1e-01
#  sersic    : (  100.21,   100.18)   22.55      8.50  *10.00*   0.31   -16.73
#  sersic    : ( {100.21}, {100.18})  20.55      4.03    2.00    0.81    60.61
# COUNTDOWN = 7
#
# Iteration : 16    Chi2nu: 2.704e+00     dChi2/Chi2: -8.67e-01   alamda: 1e-02
#  sersic    : (  100.23,   100.19)   22.72     18.76    3.38    0.46   -14.57
#  sersic    : ( {100.23}, {100.19})  20.72      4.32    2.00    0.86    54.08
# COUNTDOWN = 84
#
# Iteration : 17    Chi2nu: 2.704e+00     dChi2/Chi2: -1.31e-08   alamda: 1e-01
#  sersic    : (  100.23,   100.19)   22.72     18.76    3.38    0.46   -14.57
#  sersic    : ( {100.23}, {100.19})  20.72      4.32    2.00    0.86    54.08
# COUNTDOWN = 10
#
# Iteration : 18    Chi2nu: 2.704e+00     dChi2/Chi2: -1.31e-08   alamda: 1e+00
#  sersic    : (  100.23,   100.19)   22.72     18.76    3.38    0.46   -14.57
#  sersic    : ( {100.23}, {100.19})  20.72      4.32    2.00    0.86    54.08
# COUNTDOWN = 9
#
# Iteration : 19    Chi2nu: 1.738e+00     dChi2/Chi2: -5.56e-01   alamda: 1e-01
#  sersic    : (  100.23,   100.19)   22.46     11.37    2.42    0.49   -12.42
#  sersic    : ( {100.23}, {100.19})  20.69      4.30    2.00    0.85    53.93
# COUNTDOWN = 81
#
# Iteration : 20    Chi2nu: 1.738e+00     dChi2/Chi2: 3.98e-08    alamda: 1e+00
#  sersic    : (  100.23,   100.19)   22.46     11.37    2.42    0.49   -12.42
#  sersic    : ( {100.23}, {100.19})  20.69      4.30    2.00    0.85    53.93
# COUNTDOWN = 10
#
# Iteration : 21    Chi2nu: 1.676e+00     dChi2/Chi2: -3.65e-02   alamda: 1e-01
#  sersic    : (  100.24,   100.20)   22.42     11.92    2.35    0.53   -11.80
#  sersic    : ( {100.24}, {100.20})  20.68      4.31    2.00    0.84    54.26
# COUNTDOWN = 79
#
# Iteration : 22    Chi2nu: 1.676e+00     dChi2/Chi2: -3.44e-08   alamda: 1e+00
#  sersic    : (  100.24,   100.20)   22.42     11.92    2.35    0.53   -11.80
#  sersic    : ( {100.24}, {100.20})  20.68      4.31    2.00    0.84    54.26
# COUNTDOWN = 10
#
# Iteration : 23    Chi2nu: 1.648e+00     dChi2/Chi2: -1.73e-02   alamda: 1e-01
#  sersic    : (  100.25,   100.20)   22.39     12.38    2.29    0.56   -11.55
#  sersic    : ( {100.25}, {100.20})  20.68      4.30    2.00    0.84    54.10
# COUNTDOWN = 77
#
# Iteration : 24    Chi2nu: 1.648e+00     dChi2/Chi2: 1.92e-08    alamda: 1e+00
#  sersic    : (  100.25,   100.20)   22.39     12.38    2.29    0.56   -11.55
#  sersic    : ( {100.25}, {100.20})  20.68      4.30    2.00    0.84    54.10
# COUNTDOWN = 10
#
# Iteration : 25    Chi2nu: 1.626e+00     dChi2/Chi2: -1.34e-02   alamda: 1e-01
#  sersic    : (  100.25,   100.21)   22.37     12.77    2.22    0.57   -11.55
#  sersic    : ( {100.25}, {100.21})  20.68      4.28    2.00    0.84    53.82
# COUNTDOWN = 75
#
# Iteration : 26    Chi2nu: 1.626e+00     dChi2/Chi2: 1.06e-08    alamda: 1e+00
#  sersic    : (  100.25,   100.21)   22.37     12.77    2.22    0.57   -11.55
#  sersic    : ( {100.25}, {100.21})  20.68      4.28    2.00    0.84    53.82
# COUNTDOWN = 10
#
# Iteration : 27    Chi2nu: 1.607e+00     dChi2/Chi2: -1.22e-02   alamda: 1e-01
#  sersic    : (  100.26,   100.21)   22.36     13.11    2.14    0.58   -11.65
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.51
# COUNTDOWN = 73
#
# Iteration : 28    Chi2nu: 1.607e+00     dChi2/Chi2: 1.97e-10    alamda: 1e+00
#  sersic    : (  100.26,   100.21)   22.36     13.11    2.14    0.58   -11.65
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.51
# COUNTDOWN = 10
#
# Iteration : 29    Chi2nu: 1.607e+00     dChi2/Chi2: 1.97e-10    alamda: 1e+01
#  sersic    : (  100.26,   100.21)   22.36     13.11    2.14    0.58   -11.65
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.51
# COUNTDOWN = 9
#
# Iteration : 30    Chi2nu: 1.597e+00     dChi2/Chi2: -6.01e-03   alamda: 1e+00
#  sersic    : (  100.26,   100.21)   22.36     13.29    2.14    0.58   -11.67
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.46
# COUNTDOWN = 70
#
# Iteration : 31    Chi2nu: 1.597e+00     dChi2/Chi2: -5.84e-10   alamda: 1e+01
#  sersic    : (  100.26,   100.21)   22.36     13.29    2.14    0.58   -11.67
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.46
# COUNTDOWN = 10
#
# Iteration : 32    Chi2nu: 1.589e+00     dChi2/Chi2: -4.68e-03   alamda: 1e+00
#  sersic    : (  100.26,   100.21)   22.36     13.45    2.13    0.59   -11.69
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.40
# COUNTDOWN = 68
#
# Iteration : 33    Chi2nu: 1.589e+00     dChi2/Chi2: -3.51e-09   alamda: 1e+01
#  sersic    : (  100.26,   100.21)   22.36     13.45    2.13    0.59   -11.69
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.40
# COUNTDOWN = 10
#
# Iteration : 34    Chi2nu: 1.583e+00     dChi2/Chi2: -3.81e-03   alamda: 1e+00
#  sersic    : (  100.26,   100.21)   22.36     13.58    2.12    0.59   -11.70
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.33
# COUNTDOWN = 66
#
# Iteration : 35    Chi2nu: 1.583e+00     dChi2/Chi2: -2.03e-08   alamda: 1e+01
#  sersic    : (  100.26,   100.21)   22.36     13.58    2.12    0.59   -11.70
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.33
# COUNTDOWN = 10
#
# Iteration : 36    Chi2nu: 1.578e+00     dChi2/Chi2: -3.24e-03   alamda: 1e+00
#  sersic    : (  100.26,   100.21)   22.36     13.71    2.11    0.59   -11.72
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.26
# COUNTDOWN = 64
#
# Iteration : 37    Chi2nu: 1.578e+00     dChi2/Chi2: -2.90e-08   alamda: 1e+01
#  sersic    : (  100.26,   100.21)   22.36     13.71    2.11    0.59   -11.72
#  sersic    : ( {100.26}, {100.21})  20.68      4.25    2.00    0.84    53.26
# COUNTDOWN = 10
#
# Iteration : 38    Chi2nu: 1.574e+00     dChi2/Chi2: -2.86e-03   alamda: 1e+00
#  sersic    : (  100.26,   100.21)   22.36     13.82    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.19
# COUNTDOWN = 62
#
# Iteration : 39    Chi2nu: 1.574e+00     dChi2/Chi2: -1.80e-08   alamda: 1e+01
#  sersic    : (  100.26,   100.21)   22.36     13.82    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.19
# COUNTDOWN = 10
#
# Iteration : 40    Chi2nu: 1.574e+00     dChi2/Chi2: -1.80e-08   alamda: 1e+02
#  sersic    : (  100.26,   100.21)   22.36     13.82    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.19
# COUNTDOWN = 9
#
# Iteration : 41    Chi2nu: 1.573e+00     dChi2/Chi2: -3.34e-04   alamda: 1e+01
#  sersic    : (  100.26,   100.21)   22.36     13.84    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.19
# COUNTDOWN = 59
#
# Iteration : 42    Chi2nu: 1.573e+00     dChi2/Chi2: -5.65e-09   alamda: 1e+02
#  sersic    : (  100.26,   100.21)   22.36     13.84    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.19
# COUNTDOWN = 10
#
# Iteration : 43    Chi2nu: 1.573e+00     dChi2/Chi2: -3.29e-04   alamda: 1e+01
#  sersic    : (  100.26,   100.21)   22.36     13.85    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.18
# COUNTDOWN = 57
#
# Iteration : 44    Chi2nu: 1.573e+00     dChi2/Chi2: 2.35e-08    alamda: 1e+02
#  sersic    : (  100.26,   100.21)   22.36     13.85    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.18
# COUNTDOWN = 10
#
# Iteration : 45    Chi2nu: 1.573e+00     dChi2/Chi2: -1.06e-04   alamda: 1e+01
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 55
#
# Iteration : 46    Chi2nu: 1.573e+00     dChi2/Chi2: -1.46e-09   alamda: 1e+02
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 10
#
# Iteration : 47    Chi2nu: 1.573e+00     dChi2/Chi2: -1.46e-09   alamda: 1e+03
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 9
#
# Iteration : 48    Chi2nu: 1.572e+00     dChi2/Chi2: -2.45e-04   alamda: 1e+02
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 52
#
# Iteration : 49    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+03
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 10
#
# Iteration : 50    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+04
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 9
#
# Iteration : 51    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+05
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 8
#
# Iteration : 52    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+06
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 7
#
# Iteration : 53    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+07
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 6
#
# Iteration : 54    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+08
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 5
#
# Iteration : 55    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+09
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 4
#
# Iteration : 56    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+10
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 3
#
# Iteration : 57    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+11
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 2
#
# Iteration : 58    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+12
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 1
#
# Iteration : 59    Chi2nu: 1.572e+00     dChi2/Chi2: -2.71e-08   alamda: 1e+13
#  sersic    : (  100.26,   100.21)   22.36     13.87    2.10    0.59   -11.73
#  sersic    : ( {100.26}, {100.21})  20.68      4.24    2.00    0.84    53.17
# COUNTDOWN = 0
# Running GALFIT...: 100%|██████████████████████████| 8/8 [04:05<00:00, 30.66s/it]
# Fit summary is now being saved into `fit.log'.

# %%
# save template images
for im in tqdm(images, desc='Getting templates...'):
    filt = im.split('_')[-4]
    gal.create_templates(obj_id, filt, num='02', oldnum='01', overwrite=True)
# Out:
# Getting templates...:  12%|██▉                    | 1/8 [00:00<00:02,  3.25it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f090w_sci.fits      # Input data image (FITS file)
# B) obj_1509_f090w_imgblock02.fits      # Output data image block
# C) obj_1509_f090w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f090w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f090w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 1                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.6285 100.7562 1 1  #  Position x, y
#  3) 23.8132     1          #  Integrated magnitude
#  4) 5.4468      1          #  R_e (effective radius)   [pix]
#  5) 3.3039      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.9276      1          #  Axis ratio (b/a)
# 10) 58.4530     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.6285 100.7562 2 2  #  Position x, y
#  3) 21.8168     1          #  Integrated magnitude
#  4) 575.3045    1          #  R_e (effective radius)   [pix]
#  5) 1.3001      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.3498      1          #  Axis ratio (b/a)
# 10) -77.6502    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...:  25%|█████▊                 | 2/8 [00:00<00:02,  3.00it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f115w_sci.fits      # Input data image (FITS file)
# B) obj_1509_f115w_imgblock02.fits      # Output data image block
# C) obj_1509_f115w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f115w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f115w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 1                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.5474 100.7511 1 1  #  Position x, y
#  3) 22.5600     1          #  Integrated magnitude
#  4) 7.4544      1          #  R_e (effective radius)   [pix]
#  5) 2.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.9016      1          #  Axis ratio (b/a)
# 10) 43.8869     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.5474 100.7511 2 2  #  Position x, y
#  3) 23.9843     1          #  Integrated magnitude
#  4) 1.3981      1          #  R_e (effective radius)   [pix]
#  5) 0.8303      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8005      1          #  Axis ratio (b/a)
# 10) 57.2046     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...:  38%|████████▋              | 3/8 [00:00<00:01,  3.08it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f150w_sci.fits      # Input data image (FITS file)
# B) obj_1509_f150w_imgblock02.fits      # Output data image block
# C) obj_1509_f150w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f150w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f150w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 1                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.5915 100.8069 1 1  #  Position x, y
#  3) 22.2844     1          #  Integrated magnitude
#  4) 2.5057      1          #  R_e (effective radius)   [pix]
#  5) 2.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8223      1          #  Axis ratio (b/a)
# 10) 55.1076     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.5915 100.8069 2 2  #  Position x, y
#  3) 22.6136     1          #  Integrated magnitude
#  4) 11.2657     1          #  R_e (effective radius)   [pix]
#  5) 0.7126      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8529      1          #  Axis ratio (b/a)
# 10) 4.8037      1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...:  50%|███████████▌           | 4/8 [00:01<00:01,  3.01it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f200w_sci.fits      # Input data image (FITS file)
# B) obj_1509_f200w_imgblock02.fits      # Output data image block
# C) obj_1509_f200w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f200w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f200w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 1                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.6026 100.7535 1 1  #  Position x, y
#  3) 21.5238     1          #  Integrated magnitude
#  4) 7.2695      1          #  R_e (effective radius)   [pix]
#  5) 2.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8980      1          #  Axis ratio (b/a)
# 10) 31.3959     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.6026 100.7535 2 2  #  Position x, y
#  3) 22.8135     1          #  Integrated magnitude
#  4) 1.3007      1          #  R_e (effective radius)   [pix]
#  5) 0.9126      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.7847      1          #  Axis ratio (b/a)
# 10) 59.5854     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...:  62%|██████████████▍        | 5/8 [00:01<00:00,  3.09it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f277w_sci.fits      # Input data image (FITS file)
# B) obj_1509_f277w_imgblock02.fits      # Output data image block
# C) obj_1509_f277w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f277w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f277w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 1                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.2937 100.2150 1 1  #  Position x, y
#  3) 22.7263     1          #  Integrated magnitude
#  4) 13.4438     1          #  R_e (effective radius)   [pix]
#  5) 2.1000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.6874      1          #  Axis ratio (b/a)
# 10) -9.0318     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.2937 100.2150 2 2  #  Position x, y
#  3) 21.0698     1          #  Integrated magnitude
#  4) 4.1770      1          #  R_e (effective radius)   [pix]
#  5) 2.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8528      1          #  Axis ratio (b/a)
# 10) 51.6652     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...:  75%|█████████████████▎     | 6/8 [00:01<00:00,  3.04it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f356w_sci.fits      # Input data image (FITS file)
# B) obj_1509_f356w_imgblock02.fits      # Output data image block
# C) obj_1509_f356w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f356w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f356w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 1                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.2999 100.2228 1 1  #  Position x, y
#  3) 22.6400     1          #  Integrated magnitude
#  4) 17.4902     1          #  R_e (effective radius)   [pix]
#  5) 2.0963      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.6089      1          #  Axis ratio (b/a)
# 10) -15.4654    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.2999 100.2228 2 2  #  Position x, y
#  3) 20.7907     1          #  Integrated magnitude
#  4) 4.4107      1          #  R_e (effective radius)   [pix]
#  5) 1.9963      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8374      1          #  Axis ratio (b/a)
# 10) 50.5290     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...:  88%|████████████████████▏  | 7/8 [00:02<00:00,  3.14it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f410m_sci.fits      # Input data image (FITS file)
# B) obj_1509_f410m_imgblock02.fits      # Output data image block
# C) obj_1509_f410m_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f410m_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f410m_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 1                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.2245 100.2167 1 1  #  Position x, y
#  3) 22.5354     1          #  Integrated magnitude
#  4) 16.2111     1          #  R_e (effective radius)   [pix]
#  5) 2.1000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.5562      1          #  Axis ratio (b/a)
# 10) -9.3545     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.2245 100.2167 2 2  #  Position x, y
#  3) 20.6375     1          #  Integrated magnitude
#  4) 4.3730      1          #  R_e (effective radius)   [pix]
#  5) 2.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8472      1          #  Axis ratio (b/a)
# 10) 53.9156     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....
# Getting templates...: 100%|███████████████████████| 8/8 [00:02<00:00,  3.09it/s]
# GALFIT Version 3.0.5 -- Apr. 23, 2013
#
#
#
#
# #  Input menu file: galfit.feedme
#
#
# ================================================================================
# # IMAGE and GALFIT CONTROL PARAMETERS
# A) obj_1509_f444w_sci.fits      # Input data image (FITS file)
# B) obj_1509_f444w_imgblock02.fits      # Output data image block
# C) obj_1509_f444w_err.fits      # Sigma image name (made from data if blank or "none")
# D) ../../../psfs/f444w_webbpsf_cutout.fits #        # Input PSF image and (optional) diffusion kernel
# E) 1                   # PSF fine sampling factor relative to data
# F) obj_1509_f444w_mask.fits      # Bad pixel mask (FITS image or ASCII coord list)
# G) constraints.txt      # File with parameter constraints (ASCII file)
# H) 1    200  1    200  # Image region to fit (xmin xmax ymin ymax)
# I) 200    200          # Size of the convolution box (x y)
# J) 28.087              # Magnitude photometric zeropoint
# K) 0.036  0.030        # Plate scale (dx dy)   [arcsec per pixel]
# O) regular             # Display type (regular, curses, both)
# P) 1                   # Choose: 0=optimize, 1=model, 2=imgblock, 3=subcomps
#
# # INITIAL FITTING PARAMETERS
# #
# #   For component type, the allowed functions are:
# #       sersic, expdisk, edgedisk, devauc, king, nuker, psf,
# #       gaussian, moffat, ferrer, and sky.
# #
# #   Hidden parameters will only appear when they're specified:
# #       Bn (n=integer, Bending Modes).
# #       C0 (diskyness/boxyness),
# #       Fn (n=integer, Azimuthal Fourier Modes).
# #       R0-R10 (coordinate rotation, for creating spiral structures).
# #       To, Ti, T0-T10 (truncation function).
# #
# # ------------------------------------------------------------------------------
# #   par)    par value(s)    fit toggle(s)    # parameter description
# # ------------------------------------------------------------------------------
#
# # Component number: 1
#  0) sersic                 #  Component type
#  1) 100.2612 100.2129 1 1  #  Position x, y
#  3) 22.3610     1          #  Integrated magnitude
#  4) 13.8669     1          #  R_e (effective radius)   [pix]
#  5) 2.1000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.5918      1          #  Axis ratio (b/a)
# 10) -11.7325    1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# # Component number: 2
#  0) sersic                 #  Component type
#  1) 100.2612 100.2129 2 2  #  Position x, y
#  3) 20.6843     1          #  Integrated magnitude
#  4) 4.2430      1          #  R_e (effective radius)   [pix]
#  5) 2.0000      1          #  Sersic index n (de Vaucouleurs n=4)
#  6) 0.0000      0          #     -----
#  7) 0.0000      0          #     -----
#  8) 0.0000      0          #     -----
#  9) 0.8374      1          #  Axis ratio (b/a)
# 10) 53.1707     1          #  Position angle (PA) [deg: Up=0, Left=90]
#  Z) 0                      #  Skip this model in output image?  (yes=1, no=0)
#
# ================================================================================
#
#
#
# -- No CCD charge diffusion kernel found or applied.
#
# -- WARNING: Convolution PSF kernel exceeds the convolution box size.
#
#
# -- Creating output image....

# %%
# make galfit plots
gal.plot_all(obj_id, field, num='01', s=50)
# Out:
# Making plots...: 100%|████████████████████████████| 8/8 [00:03<00:00,  2.31it/s]

# %%
# make aperture plots
gal.plot_all_apertures(obj_id, field, num='01', frac_hl=1.5)
# Out:
# Making plots...:   0%|                                    | 0/8 [00:00<?, ?it/s]/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:406: RuntimeWarning: invalid value encountered in log10
# /Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:420: RuntimeWarning: invalid value encountered in log10
# Making plots...:  12%|███▌                        | 1/8 [00:03<00:23,  3.31s/it]/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:406: RuntimeWarning: invalid value encountered in log10
# /Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:420: RuntimeWarning: invalid value encountered in log10
# Making plots...:  25%|███████                     | 2/8 [00:07<00:22,  3.79s/it]WARNING: No meaningful fit was possible. [photutils.isophote.ellipse]
# /Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:406: RuntimeWarning: invalid value encountered in log10
# /Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:420: RuntimeWarning: invalid value encountered in log10
# Making plots...:  50%|██████████████              | 4/8 [00:12<00:11,  2.93s/it]/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:406: RuntimeWarning: invalid value encountered in log10
# /Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:420: RuntimeWarning: invalid value encountered in log10
# Making plots...:  62%|█████████████████▌          | 5/8 [00:18<00:11,  3.97s/it]/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:401: RuntimeWarning: invalid value encountered in log10
# /Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:406: RuntimeWarning: invalid value encountered in log10
# /Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:420: RuntimeWarning: invalid value encountered in log10
# Making plots...:  75%|█████████████████████       | 6/8 [00:23<00:08,  4.34s/it]/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:406: RuntimeWarning: invalid value encountered in log10
# /Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:420: RuntimeWarning: invalid value encountered in log10
# Making plots...:  88%|████████████████████████▌   | 7/8 [00:29<00:04,  4.84s/it]/Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:406: RuntimeWarning: invalid value encountered in log10
# /Users/jakesummers7200/JWST/PEARLS/GALAXY_HALOS_PAPER/GalPy/Galfit.py:420: RuntimeWarning: invalid value encountered in log10
# Making plots...: 100%|████████████████████████████| 8/8 [00:35<00:00,  4.43s/it]
